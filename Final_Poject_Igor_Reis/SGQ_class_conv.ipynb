# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report, auc, precision_recall_curve, roc_curve
import matplotlib.pyplot as plt
from sklearn.utils import class_weight

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/85/a3/c0eab9dd6a894165e2cb87504ff5b2710ac5ede3447d9138620b7341b6a2/shap-0.37.0.tar.gz (326kB)
#      |████████████████████████████████| 327kB 8.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.41.1)
# Collecting slicer==0.0.3
#   Downloading https://files.pythonhosted.org/packages/02/a6/c708c5a0f338e99cfbcb6288b88794525548e4fc1b8457feec2c552a81a4/slicer-0.0.3-py3-none-any.whl
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from shap) (0.48.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (0.17.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->shap) (50.3.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->shap) (0.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.37.0-cp36-cp36m-linux_x86_64.whl size=463909 sha256=3fcb9400ce52986fb30db62cc30e785402ac6068d9c602fd3f87f19b2d907eb4
#   Stored in directory: /root/.cache/pip/wheels/df/ad/b0/aa7815ec68850d66551ef618095eccb962c8f6022f1d3dd989
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.37.0 slicer-0.0.3

# %%
import shap

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/your_project_folder/'  #change dir to your project folder
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Star_galaxy_stripe82.csv')

# %%
data = df.copy()

# %%
data.head()
# Out:
#       specObjID        ra       dec  ... petroMagErr_r  petroMag_i  petroMagErr_i
# 0  4.380402e+17  3.606484 -0.141486  ...      0.025818    17.16036       0.027270
# 1  4.380405e+17  3.637356 -0.175298  ...      0.016762    16.99493       0.019215
# 2  4.380408e+17  3.722365 -0.474311  ...      0.019360    18.91112       0.017962
# 3  4.380411e+17  3.654366 -0.262900  ...      0.008431    16.08835       0.008618
# 4  4.380413e+17  3.172661 -1.053429  ...      0.022735    17.37941       0.020684
#
# [5 rows x 14 columns]

# %%
data.drop(columns = ['specObjID', 'ra', 'dec', 'z', 'zErr'], axis = 1, inplace = True)

# %%
mapping = {'STAR': 0, 'GALAXY': 1, 'QSO': 2}

data = data.replace({'class': mapping})

# %%
data.head()
# Out:
#    class  petroMag_u  petroMagErr_u  ...  petroMagErr_r  petroMag_i  petroMagErr_i
# 0      1    19.18945       0.148011  ...       0.025818    17.16036       0.027270
# 1      1    19.98902       0.167935  ...       0.016762    16.99493       0.019215
# 2      2    19.56212       0.034653  ...       0.019360    18.91112       0.017962
# 3      1    19.03313       0.105097  ...       0.008431    16.08835       0.008618
# 4      1    19.48644       0.110411  ...       0.022735    17.37941       0.020684
#
# [5 rows x 9 columns]

# %%
data = data[data['petroMag_u'] > 0]
data = data[data['petroMagErr_u'] > 0]
data = data[data['petroMag_g'] > 0]
data = data[data['petroMagErr_g'] > 0]
data = data[data['petroMag_r'] > 0]
data = data[data['petroMagErr_r'] > 0]
data = data[data['petroMag_i'] > 0]
data = data[data['petroMagErr_i'] > 0]

# %%
data = data[data['petroMag_u'] < 100]
data = data[data['petroMagErr_u'] < np.max(data['petroMag_u'])/10]
data = data[data['petroMag_g'] < 100]
data = data[data['petroMagErr_g'] < np.max(data['petroMag_g'])/10]
data = data[data['petroMag_r'] < 100]
data = data[data['petroMagErr_r'] < np.max(data['petroMag_r'])/10]
data = data[data['petroMag_i'] < 100]
data = data[data['petroMagErr_i'] < np.max(data['petroMag_i'])/10]

# %%
sns.countplot(x = 'class', data = data)

# %%
data['class'].value_counts()
# Out:
# 1    93304
# 0    54231
# 2    37117
# Name: class, dtype: int64

# %%
y = data['class']

# %% [markdown]
# # Comparações entre baseline e modelo com pesos.

# %% [markdown]
# ---
# Modelo Baseline
#
#
# ---

# %%
yt = data['class']

# %%
x_datat = data.drop(['class'], axis = 1)

# %%
xt = (x_datat - np.min(x_datat))/(np.max(x_datat) - np.min(x_datat))

# %%
xconvt = np.array(xt).reshape(np.array(xt).shape[0], np.array(xt).shape[1],1)
xconvt.shape
# Out:
# (184652, 8, 1)

# %%
x_traint, x_testt, y_traint, y_testt = train_test_split(xconvt, yt, test_size = 0.2, random_state = 3) 

model = Sequential()

model.add(Conv1D(64, 2, activation = 'relu', input_shape = (8, 1)))
model.add(Flatten())
model.add(Dense(3, activation = 'softmax'))

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
historyt = model.fit(
    x_traint,
    to_categorical(y_traint),
    epochs = 20,
    batch_size = 128,
    validation_data = (
        x_testt,
        to_categorical(y_testt)
    )
)
# Out:
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8185 - accuracy: 0.6345 - val_loss: 0.7295 - val_accuracy: 0.6887
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6806 - accuracy: 0.7472 - val_loss: 0.6377 - val_accuracy: 0.7838
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6140 - accuracy: 0.7927 - val_loss: 0.5883 - val_accuracy: 0.8040
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5737 - accuracy: 0.8116 - val_loss: 0.5552 - val_accuracy: 0.8197
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.8206 - val_loss: 0.5298 - val_accuracy: 0.8240
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5232 - accuracy: 0.8270 - val_loss: 0.5158 - val_accuracy: 0.8284
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5066 - accuracy: 0.8320 - val_loss: 0.5000 - val_accuracy: 0.8300
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4928 - accuracy: 0.8363 - val_loss: 0.4837 - val_accuracy: 0.8410
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4813 - accuracy: 0.8395 - val_loss: 0.4727 - val_accuracy: 0.8467
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4718 - accuracy: 0.8420 - val_loss: 0.4673 - val_accuracy: 0.8431
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4638 - accuracy: 0.8445 - val_loss: 0.4568 - val_accuracy: 0.8457
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4566 - accuracy: 0.8467 - val_loss: 0.4491 - val_accuracy: 0.8494
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4508 - accuracy: 0.8481 - val_loss: 0.4439 - val_accuracy: 0.8504
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4451 - accuracy: 0.8500 - val_loss: 0.4388 - val_accuracy: 0.8546
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4410 - accuracy: 0.8505 - val_loss: 0.4347 - val_accuracy: 0.8530
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4370 - accuracy: 0.8520 - val_loss: 0.4302 - val_accuracy: 0.8544
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4333 - accuracy: 0.8529 - val_loss: 0.4278 - val_accuracy: 0.8556
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4299 - accuracy: 0.8530 - val_loss: 0.4232 - val_accuracy: 0.8573
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4271 - accuracy: 0.8546 - val_loss: 0.4225 - val_accuracy: 0.8560
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4248 - accuracy: 0.8545 - val_loss: 0.4181 - val_accuracy: 0.8565

# %%
test_predt = model.predict(x_testt)

# %%
plt.plot(historyt.history['accuracy'], label = 'Train Accuracy')
plt.plot(historyt.history['val_accuracy'], label = 'Val Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Épocas')
plt.legend()

# %%
plt.plot(historyt.history['loss'], label = 'Train Loss')
plt.plot(historyt.history['val_loss'], label = 'Val Loss')
plt.ylabel('Loss')
plt.xlabel('Épocas')
plt.legend()

# %%
label = ['Star', 'Galaxy', 'Quasar']
for i in range(3):
  fprt, tprt, _ = roc_curve(to_categorical(np.array(y_testt))[:,i], test_predt[:,i])
  plt.plot(fprt, tprt, label = '{}: área = {:.2f}'.format(label[i],auc(fprt, tprt)))

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
for i in range(3):
  precisiont, recallt, _ = precision_recall_curve(to_categorical(np.array(y_testt))[:, i],test_predt[:, i])
  plt.plot(recallt, precisiont, label = '{}: área = {:.2f}'.format(label[i],auc(recallt, precisiont)))

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
cmatrixt = confusion_matrix(np.array(y_testt), np.argmax(test_predt, axis = 1))
cmatrixt
# Out:
# array([[ 8959,   807,  1043],
#        [  322, 17682,   727],
#        [  589,  1811,  4991]])

# %%
sns.heatmap(cmatrixt, xticklabels = label, yticklabels = label, annot = True, fmt = '10')

# %%
y_testt.value_counts()
# Out:
# 1    18731
# 0    10809
# 2     7391
# Name: class, dtype: int64

# %%
reportt = classification_report(y_testt, np.argmax(test_predt, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
reportt = pd.DataFrame(reportt)
reportt.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
reportt
# Out:
#                Star    Galaxy       QSO
# precision  0.907700  0.871034  0.738204
# recall     0.828846  0.943997  0.675281
# f1-score   0.866483  0.906049  0.705342

# %% [markdown]
# ---
# Modelo com pesos.
#
#
# ---

# %%
yt2 = data['class']

# %%
x_datat2 = data.drop(['class'], axis = 1)

# %%
xt2 = (x_datat2 - np.min(x_datat2))/(np.max(x_datat2) - np.min(x_datat2))

# %%
xconvt2 = np.array(xt2).reshape(np.array(xt2).shape[0], np.array(xt2).shape[1],1)
xconvt2.shape
# Out:
# (184652, 8, 1)

# %%
x_traint2, x_testt2, y_traint2, y_testt2 = train_test_split(xconvt2, yt2, test_size = 0.2, random_state = 3) 

class_weights = class_weight.compute_class_weight(
    'balanced',
    np.unique(y_traint2),
    y_traint2
)
class_weights = {i  :class_weights[i] for i in range(3)}

model = Sequential()

model.add(Conv1D(64, 2, activation = 'relu', input_shape = (8, 1)))
model.add(Flatten())
model.add(Dense(3, activation = 'softmax'))

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
historyt2 = model.fit(
    x_traint2,
    to_categorical(y_traint2),
    epochs = 20,
    batch_size = 128,
    validation_data = (x_testt2, to_categorical(y_testt2)),
    class_weight = class_weights
)
# Out:
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8424 - accuracy: 0.5770 - val_loss: 0.7888 - val_accuracy: 0.6173
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7212 - accuracy: 0.6461 - val_loss: 0.7427 - val_accuracy: 0.6444
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6696 - accuracy: 0.6918 - val_loss: 0.6830 - val_accuracy: 0.6853
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6378 - accuracy: 0.7309 - val_loss: 0.6445 - val_accuracy: 0.7404
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6119 - accuracy: 0.7573 - val_loss: 0.6208 - val_accuracy: 0.7513
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5896 - accuracy: 0.7741 - val_loss: 0.5898 - val_accuracy: 0.7694
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5709 - accuracy: 0.7884 - val_loss: 0.5582 - val_accuracy: 0.7990
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7963 - val_loss: 0.5432 - val_accuracy: 0.8040
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.8043 - val_loss: 0.5302 - val_accuracy: 0.8086
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.8102 - val_loss: 0.4951 - val_accuracy: 0.8274
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5252 - accuracy: 0.8148 - val_loss: 0.5339 - val_accuracy: 0.8006
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5185 - accuracy: 0.8186 - val_loss: 0.4869 - val_accuracy: 0.8308
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5120 - accuracy: 0.8225 - val_loss: 0.4781 - val_accuracy: 0.8348
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5073 - accuracy: 0.8241 - val_loss: 0.4730 - val_accuracy: 0.8387
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5032 - accuracy: 0.8265 - val_loss: 0.4731 - val_accuracy: 0.8348
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4992 - accuracy: 0.8296 - val_loss: 0.4967 - val_accuracy: 0.8211
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4962 - accuracy: 0.8299 - val_loss: 0.4685 - val_accuracy: 0.8372
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4931 - accuracy: 0.8322 - val_loss: 0.4655 - val_accuracy: 0.8398
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4902 - accuracy: 0.8335 - val_loss: 0.4779 - val_accuracy: 0.8311
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4884 - accuracy: 0.8345 - val_loss: 0.4663 - val_accuracy: 0.8385

# %%
test_predt2 = model.predict(x_testt2)

# %%
plt.plot(historyt2.history['accuracy'], label = 'Train Accuracy')
plt.plot(historyt2.history['val_accuracy'], label = 'Val Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Épocas')
plt.legend()

# %%
plt.plot(historyt2.history['loss'], label = 'Train Loss')
plt.plot(historyt2.history['val_loss'], label = 'Val Loss')
plt.ylabel('Loss')
plt.xlabel('Épocas')
plt.legend()

# %%
label = ['Star', 'Galaxy', 'Quasar']
for i in range(3):
  fprt2, tprt2, _ = roc_curve(to_categorical(np.array(y_testt2))[:,i], test_predt2[:,i])
  plt.plot(fprt2, tprt2, label = '{}: área = {:.2f}'.format(label[i],auc(fprt2, tprt2)))

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
for i in range(3):
  precisiont2, recallt2, _ = precision_recall_curve(to_categorical(np.array(y_testt2))[:, i],test_predt2[:, i])
  plt.plot(recallt2, precisiont2, label = '{}: área = {:.2f}'.format(label[i],auc(recallt2, precisiont2)))

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
cmatrixt2 = confusion_matrix(np.array(y_testt2), np.argmax(test_predt2, axis = 1))
cmatrixt2
# Out:
# array([[ 8923,   577,  1309],
#        [  678, 16267,  1786],
#        [  477,  1136,  5778]])

# %%
sns.heatmap(cmatrixt2, xticklabels = label, yticklabels = label, annot = True, fmt = '10')

# %%
y_testt2.value_counts()
# Out:
# 1    18731
# 0    10809
# 2     7391
# Name: class, dtype: int64

# %%
reportt2 = classification_report(y_testt2, np.argmax(test_predt2, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
reportt2 = pd.DataFrame(reportt2)
reportt2.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
reportt2
# Out:
#                Star    Galaxy       QSO
# precision  0.885394  0.904727  0.651189
# recall     0.825516  0.868453  0.781762
# f1-score   0.854407  0.886219  0.710526

# %% [markdown]
# ---
# # Cross validation
#
# Vamos começar com a rede menos profunda

# %%
x_data = data.drop(['class'], axis = 1)

# %%
x = (x_data - np.min(x_data))/(np.max(x_data) - np.min(x_data))

# %%
xconv = np.array(x).reshape(np.array(x).shape[0], np.array(x).shape[1],1)
xconv.shape
# Out:
# (184652, 8, 1)

# %%
folds = 10
n_classes = 3

train_acc = []
train_loss = []

val_acc = []
val_loss = []

# For each class
precision = [{}]*folds
recall = [{}]*folds
average_precision = [{}]*folds

fpr = [{}]*folds
tpr = [{}]*folds
roc_auc = [{}]*folds

train_accw = []
train_lossw = []

val_accw = []
val_lossw = []

# For each class
precisionw = [{}]*folds
recallw = [{}]*folds
average_precisionw = [{}]*folds

fprw = [{}]*folds
tprw = [{}]*folds
roc_aucw = [{}]*folds

for i in range(folds):
  x_train, x_test, y_train, y_test = train_test_split(xconv, y, test_size = 0.2, random_state = i) 

  model = Sequential()

  model.add(Conv1D(64, 2, activation = 'relu', input_shape = (8, 1)))
  model.add(Flatten())
  model.add(Dense(3, activation = 'softmax'))

  model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

  history = model.fit(
    x_train,
    to_categorical(y_train),
    epochs = 20,
    batch_size = 128,
    validation_data = (
        x_test,
        to_categorical(y_test)
    )
)
  
  test_pred = model.predict(x_test)
  
  train_acc.append(history.history['accuracy'])
  train_loss.append(history.history['loss'])

  val_acc.append(history.history['val_accuracy'])
  val_loss.append(history.history['val_loss'])

  #----------------------------------------------------------------------------#
  x_trainw, x_testw, y_trainw, y_testw = train_test_split(xconv, y, test_size = 0.2, random_state = i) 

  class_weights = class_weight.compute_class_weight(
    'balanced',
    np.unique(y_trainw),
    y_trainw
  )
  class_weights = {i  :class_weights[i] for i in range(3)}

  modelw = Sequential()

  modelw.add(Conv1D(64, 2, activation = 'relu', input_shape = (8, 1)))
  modelw.add(Flatten())
  modelw.add(Dense(3, activation = 'softmax'))

  modelw.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

  historyw = modelw.fit(
    x_train,
    to_categorical(y_train),
    epochs = 20,
    batch_size = 128,
    validation_data = (
        x_test,
        to_categorical(y_test)),
        class_weight = class_weights
)


  test_predw = modelw.predict(x_testw)
  
  train_accw.append(historyw.history['accuracy'])
  train_lossw.append(historyw.history['loss'])

  val_accw.append(historyw.history['val_accuracy'])
  val_lossw.append(historyw.history['val_loss'])

  for j in range(n_classes):
      precision[i][j], recall[i][j], _ = precision_recall_curve(to_categorical(np.array(y_test))[:, j],test_pred[:, j])
      precisionw[i][j], recallw[i][j], _ = precision_recall_curve(to_categorical(np.array(y_testw))[:, j],test_predw[:, j])

  for j in range(n_classes):
    fpr[i][j], tpr[i][j], _ = roc_curve(to_categorical(np.array(y_test))[:,j], test_pred[:,j])
    fprw[i][j], tprw[i][j], _ = roc_curve(to_categorical(np.array(y_testw))[:,j], test_predw[:,j])
# Out:
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8267 - accuracy: 0.6294 - val_loss: 0.7537 - val_accuracy: 0.7006
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7146 - accuracy: 0.7256 - val_loss: 0.6804 - val_accuracy: 0.7495
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6499 - accuracy: 0.7698 - val_loss: 0.6299 - val_accuracy: 0.7957
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6105 - accuracy: 0.7942 - val_loss: 0.5952 - val_accuracy: 0.8056
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5831 - accuracy: 0.8071 - val_loss: 0.5727 - val_accuracy: 0.8134
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.8158 - val_loss: 0.5614 - val_accuracy: 0.8207
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.8222 - val_loss: 0.5362 - val_accuracy: 0.8228
# Epoch 8/20
# 1155/1155 [==============================] - 3s 3ms/step - loss: 0.5287 - accuracy: 0.8262 - val_loss: 0.5239 - val_accuracy: 0.8238
# Epoch 9/20
# 1155/1155 [==============================] - 3s 3ms/step - loss: 0.5165 - accuracy: 0.8299 - val_loss: 0.5141 - val_accuracy: 0.8332
# Epoch 10/20
# 1155/1155 [==============================] - 3s 3ms/step - loss: 0.5064 - accuracy: 0.8324 - val_loss: 0.5032 - val_accuracy: 0.8330
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4972 - accuracy: 0.8351 - val_loss: 0.4956 - val_accuracy: 0.8335
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4891 - accuracy: 0.8379 - val_loss: 0.4933 - val_accuracy: 0.8325
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4818 - accuracy: 0.8388 - val_loss: 0.4812 - val_accuracy: 0.8400
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4752 - accuracy: 0.8416 - val_loss: 0.4776 - val_accuracy: 0.8390
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4696 - accuracy: 0.8427 - val_loss: 0.4708 - val_accuracy: 0.8424
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4644 - accuracy: 0.8440 - val_loss: 0.4664 - val_accuracy: 0.8422
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4602 - accuracy: 0.8456 - val_loss: 0.4663 - val_accuracy: 0.8452
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4559 - accuracy: 0.8475 - val_loss: 0.4596 - val_accuracy: 0.8435
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4524 - accuracy: 0.8481 - val_loss: 0.4557 - val_accuracy: 0.8460
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4486 - accuracy: 0.8489 - val_loss: 0.4516 - val_accuracy: 0.8489
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8385 - accuracy: 0.5844 - val_loss: 0.7709 - val_accuracy: 0.6385
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7103 - accuracy: 0.6578 - val_loss: 0.7194 - val_accuracy: 0.6687
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6641 - accuracy: 0.7024 - val_loss: 0.6467 - val_accuracy: 0.7470
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6361 - accuracy: 0.7395 - val_loss: 0.6586 - val_accuracy: 0.7137
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6129 - accuracy: 0.7615 - val_loss: 0.6088 - val_accuracy: 0.7678
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5936 - accuracy: 0.7757 - val_loss: 0.6019 - val_accuracy: 0.7630
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5766 - accuracy: 0.7862 - val_loss: 0.5749 - val_accuracy: 0.7776
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5620 - accuracy: 0.7968 - val_loss: 0.5558 - val_accuracy: 0.7885
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.8036 - val_loss: 0.5220 - val_accuracy: 0.8170
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.8098 - val_loss: 0.5453 - val_accuracy: 0.7997
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.8153 - val_loss: 0.5149 - val_accuracy: 0.8111
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5229 - accuracy: 0.8184 - val_loss: 0.5078 - val_accuracy: 0.8178
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5166 - accuracy: 0.8220 - val_loss: 0.5118 - val_accuracy: 0.8136
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5111 - accuracy: 0.8243 - val_loss: 0.5021 - val_accuracy: 0.8181
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5063 - accuracy: 0.8268 - val_loss: 0.5150 - val_accuracy: 0.8123
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5019 - accuracy: 0.8291 - val_loss: 0.5149 - val_accuracy: 0.8111
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4983 - accuracy: 0.8315 - val_loss: 0.4697 - val_accuracy: 0.8369
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4949 - accuracy: 0.8335 - val_loss: 0.4913 - val_accuracy: 0.8223
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4917 - accuracy: 0.8345 - val_loss: 0.4823 - val_accuracy: 0.8295
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4888 - accuracy: 0.8362 - val_loss: 0.4834 - val_accuracy: 0.8286
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8234 - accuracy: 0.6263 - val_loss: 0.7415 - val_accuracy: 0.6998
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6965 - accuracy: 0.7276 - val_loss: 0.6588 - val_accuracy: 0.7584
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6315 - accuracy: 0.7777 - val_loss: 0.6064 - val_accuracy: 0.8006
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5902 - accuracy: 0.8032 - val_loss: 0.5753 - val_accuracy: 0.8209
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5620 - accuracy: 0.8147 - val_loss: 0.5495 - val_accuracy: 0.8224
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.8226 - val_loss: 0.5314 - val_accuracy: 0.8272
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5238 - accuracy: 0.8271 - val_loss: 0.5178 - val_accuracy: 0.8305
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5103 - accuracy: 0.8313 - val_loss: 0.5079 - val_accuracy: 0.8260
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4992 - accuracy: 0.8343 - val_loss: 0.4963 - val_accuracy: 0.8306
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4898 - accuracy: 0.8368 - val_loss: 0.4866 - val_accuracy: 0.8430
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4807 - accuracy: 0.8393 - val_loss: 0.4820 - val_accuracy: 0.8342
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4739 - accuracy: 0.8413 - val_loss: 0.4707 - val_accuracy: 0.8416
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4676 - accuracy: 0.8430 - val_loss: 0.4645 - val_accuracy: 0.8442
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4622 - accuracy: 0.8442 - val_loss: 0.4582 - val_accuracy: 0.8467
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4570 - accuracy: 0.8461 - val_loss: 0.4538 - val_accuracy: 0.8484
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4524 - accuracy: 0.8473 - val_loss: 0.4495 - val_accuracy: 0.8489
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4491 - accuracy: 0.8477 - val_loss: 0.4466 - val_accuracy: 0.8511
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4448 - accuracy: 0.8490 - val_loss: 0.4429 - val_accuracy: 0.8515
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4420 - accuracy: 0.8500 - val_loss: 0.4466 - val_accuracy: 0.8462
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4392 - accuracy: 0.8505 - val_loss: 0.4426 - val_accuracy: 0.8509
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8353 - accuracy: 0.5867 - val_loss: 0.7674 - val_accuracy: 0.6393
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7044 - accuracy: 0.6671 - val_loss: 0.6863 - val_accuracy: 0.7144
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6475 - accuracy: 0.7274 - val_loss: 0.6401 - val_accuracy: 0.7481
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6111 - accuracy: 0.7638 - val_loss: 0.6116 - val_accuracy: 0.7611
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5843 - accuracy: 0.7827 - val_loss: 0.5526 - val_accuracy: 0.8072
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5632 - accuracy: 0.7954 - val_loss: 0.5364 - val_accuracy: 0.8102
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.8053 - val_loss: 0.5274 - val_accuracy: 0.8103
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.8118 - val_loss: 0.5262 - val_accuracy: 0.8122
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5217 - accuracy: 0.8173 - val_loss: 0.5085 - val_accuracy: 0.8185
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5124 - accuracy: 0.8228 - val_loss: 0.4951 - val_accuracy: 0.8238
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.8262 - val_loss: 0.5127 - val_accuracy: 0.8122
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4985 - accuracy: 0.8303 - val_loss: 0.4905 - val_accuracy: 0.8257
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4931 - accuracy: 0.8341 - val_loss: 0.4691 - val_accuracy: 0.8389
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4882 - accuracy: 0.8365 - val_loss: 0.4689 - val_accuracy: 0.8383
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4845 - accuracy: 0.8381 - val_loss: 0.4602 - val_accuracy: 0.8421
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4807 - accuracy: 0.8404 - val_loss: 0.4797 - val_accuracy: 0.8287
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4780 - accuracy: 0.8412 - val_loss: 0.4664 - val_accuracy: 0.8403
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4750 - accuracy: 0.8428 - val_loss: 0.4623 - val_accuracy: 0.8386
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4729 - accuracy: 0.8434 - val_loss: 0.4623 - val_accuracy: 0.8405
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4701 - accuracy: 0.8450 - val_loss: 0.4342 - val_accuracy: 0.8526
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8161 - accuracy: 0.6369 - val_loss: 0.7301 - val_accuracy: 0.7007
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6856 - accuracy: 0.7417 - val_loss: 0.6437 - val_accuracy: 0.7648
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6174 - accuracy: 0.7893 - val_loss: 0.5935 - val_accuracy: 0.8097
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5756 - accuracy: 0.8097 - val_loss: 0.5588 - val_accuracy: 0.8115
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.8202 - val_loss: 0.5332 - val_accuracy: 0.8257
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5253 - accuracy: 0.8264 - val_loss: 0.5200 - val_accuracy: 0.8242
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5085 - accuracy: 0.8320 - val_loss: 0.5024 - val_accuracy: 0.8423
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4947 - accuracy: 0.8364 - val_loss: 0.4875 - val_accuracy: 0.8378
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4835 - accuracy: 0.8394 - val_loss: 0.4772 - val_accuracy: 0.8406
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4739 - accuracy: 0.8420 - val_loss: 0.4672 - val_accuracy: 0.8467
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4653 - accuracy: 0.8441 - val_loss: 0.4623 - val_accuracy: 0.8454
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4580 - accuracy: 0.8464 - val_loss: 0.4543 - val_accuracy: 0.8479
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4521 - accuracy: 0.8475 - val_loss: 0.4472 - val_accuracy: 0.8518
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4475 - accuracy: 0.8485 - val_loss: 0.4462 - val_accuracy: 0.8476
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4428 - accuracy: 0.8500 - val_loss: 0.4393 - val_accuracy: 0.8519
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4390 - accuracy: 0.8509 - val_loss: 0.4367 - val_accuracy: 0.8527
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4356 - accuracy: 0.8509 - val_loss: 0.4329 - val_accuracy: 0.8543
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4327 - accuracy: 0.8521 - val_loss: 0.4345 - val_accuracy: 0.8541
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4298 - accuracy: 0.8531 - val_loss: 0.4276 - val_accuracy: 0.8555
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4275 - accuracy: 0.8531 - val_loss: 0.4267 - val_accuracy: 0.8553
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8466 - accuracy: 0.5797 - val_loss: 0.8061 - val_accuracy: 0.6091
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7256 - accuracy: 0.6444 - val_loss: 0.7240 - val_accuracy: 0.6630
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6761 - accuracy: 0.6868 - val_loss: 0.6688 - val_accuracy: 0.7268
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6479 - accuracy: 0.7230 - val_loss: 0.6404 - val_accuracy: 0.7449
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6256 - accuracy: 0.7484 - val_loss: 0.6150 - val_accuracy: 0.7599
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6059 - accuracy: 0.7650 - val_loss: 0.5995 - val_accuracy: 0.7712
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5888 - accuracy: 0.7754 - val_loss: 0.5549 - val_accuracy: 0.8045
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5735 - accuracy: 0.7857 - val_loss: 0.5736 - val_accuracy: 0.7754
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7933 - val_loss: 0.5554 - val_accuracy: 0.7907
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.8010 - val_loss: 0.5383 - val_accuracy: 0.8043
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.8062 - val_loss: 0.5142 - val_accuracy: 0.8164
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.8110 - val_loss: 0.5109 - val_accuracy: 0.8187
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5227 - accuracy: 0.8154 - val_loss: 0.4984 - val_accuracy: 0.8241
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5170 - accuracy: 0.8186 - val_loss: 0.5046 - val_accuracy: 0.8194
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5120 - accuracy: 0.8216 - val_loss: 0.4874 - val_accuracy: 0.8277
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5073 - accuracy: 0.8239 - val_loss: 0.4796 - val_accuracy: 0.8363
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5033 - accuracy: 0.8263 - val_loss: 0.4765 - val_accuracy: 0.8344
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4999 - accuracy: 0.8281 - val_loss: 0.4647 - val_accuracy: 0.8405
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4963 - accuracy: 0.8304 - val_loss: 0.4686 - val_accuracy: 0.8379
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4939 - accuracy: 0.8318 - val_loss: 0.4644 - val_accuracy: 0.8389
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8207 - accuracy: 0.6343 - val_loss: 0.7388 - val_accuracy: 0.6930
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7020 - accuracy: 0.7285 - val_loss: 0.6664 - val_accuracy: 0.7485
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6423 - accuracy: 0.7693 - val_loss: 0.6193 - val_accuracy: 0.7859
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6055 - accuracy: 0.7916 - val_loss: 0.5951 - val_accuracy: 0.7989
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5780 - accuracy: 0.8061 - val_loss: 0.5640 - val_accuracy: 0.8110
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.8159 - val_loss: 0.5407 - val_accuracy: 0.8252
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.8239 - val_loss: 0.5287 - val_accuracy: 0.8329
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5157 - accuracy: 0.8303 - val_loss: 0.5076 - val_accuracy: 0.8269
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5006 - accuracy: 0.8349 - val_loss: 0.4921 - val_accuracy: 0.8432
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4884 - accuracy: 0.8386 - val_loss: 0.4814 - val_accuracy: 0.8458
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4783 - accuracy: 0.8412 - val_loss: 0.4696 - val_accuracy: 0.8471
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4702 - accuracy: 0.8437 - val_loss: 0.4657 - val_accuracy: 0.8510
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4638 - accuracy: 0.8456 - val_loss: 0.4584 - val_accuracy: 0.8455
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4586 - accuracy: 0.8466 - val_loss: 0.4530 - val_accuracy: 0.8510
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4539 - accuracy: 0.8483 - val_loss: 0.4588 - val_accuracy: 0.8513
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4501 - accuracy: 0.8493 - val_loss: 0.4424 - val_accuracy: 0.8539
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4463 - accuracy: 0.8504 - val_loss: 0.4422 - val_accuracy: 0.8558
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4432 - accuracy: 0.8514 - val_loss: 0.4371 - val_accuracy: 0.8556
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4403 - accuracy: 0.8521 - val_loss: 0.4347 - val_accuracy: 0.8565
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4377 - accuracy: 0.8525 - val_loss: 0.4327 - val_accuracy: 0.8569
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8384 - accuracy: 0.5814 - val_loss: 0.8085 - val_accuracy: 0.6046
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7066 - accuracy: 0.6646 - val_loss: 0.7244 - val_accuracy: 0.6556
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6558 - accuracy: 0.7189 - val_loss: 0.6371 - val_accuracy: 0.7566
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6249 - accuracy: 0.7515 - val_loss: 0.6194 - val_accuracy: 0.7649
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6017 - accuracy: 0.7712 - val_loss: 0.5911 - val_accuracy: 0.7841
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5832 - accuracy: 0.7841 - val_loss: 0.5772 - val_accuracy: 0.7850
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5681 - accuracy: 0.7931 - val_loss: 0.5699 - val_accuracy: 0.7965
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.8014 - val_loss: 0.5490 - val_accuracy: 0.7985
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.8079 - val_loss: 0.5260 - val_accuracy: 0.8121
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.8130 - val_loss: 0.5296 - val_accuracy: 0.8062
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5243 - accuracy: 0.8171 - val_loss: 0.5202 - val_accuracy: 0.8152
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5171 - accuracy: 0.8210 - val_loss: 0.5043 - val_accuracy: 0.8198
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5110 - accuracy: 0.8242 - val_loss: 0.4949 - val_accuracy: 0.8263
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5057 - accuracy: 0.8267 - val_loss: 0.4827 - val_accuracy: 0.8307
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5007 - accuracy: 0.8289 - val_loss: 0.4684 - val_accuracy: 0.8372
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4964 - accuracy: 0.8316 - val_loss: 0.4748 - val_accuracy: 0.8364
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4928 - accuracy: 0.8334 - val_loss: 0.4788 - val_accuracy: 0.8334
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4889 - accuracy: 0.8352 - val_loss: 0.4647 - val_accuracy: 0.8405
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4867 - accuracy: 0.8363 - val_loss: 0.4702 - val_accuracy: 0.8364
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4839 - accuracy: 0.8375 - val_loss: 0.4691 - val_accuracy: 0.8354
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8155 - accuracy: 0.6394 - val_loss: 0.7327 - val_accuracy: 0.7060
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6807 - accuracy: 0.7493 - val_loss: 0.6449 - val_accuracy: 0.7899
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6109 - accuracy: 0.7931 - val_loss: 0.5913 - val_accuracy: 0.8048
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5687 - accuracy: 0.8123 - val_loss: 0.5577 - val_accuracy: 0.8252
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.8222 - val_loss: 0.5321 - val_accuracy: 0.8251
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5183 - accuracy: 0.8286 - val_loss: 0.5139 - val_accuracy: 0.8290
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5019 - accuracy: 0.8330 - val_loss: 0.4991 - val_accuracy: 0.8366
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4889 - accuracy: 0.8371 - val_loss: 0.4867 - val_accuracy: 0.8363
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4782 - accuracy: 0.8403 - val_loss: 0.4787 - val_accuracy: 0.8422
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4690 - accuracy: 0.8428 - val_loss: 0.4687 - val_accuracy: 0.8411
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4614 - accuracy: 0.8454 - val_loss: 0.4663 - val_accuracy: 0.8395
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4552 - accuracy: 0.8467 - val_loss: 0.4590 - val_accuracy: 0.8460
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4502 - accuracy: 0.8484 - val_loss: 0.4533 - val_accuracy: 0.8481
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4455 - accuracy: 0.8500 - val_loss: 0.4463 - val_accuracy: 0.8484
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4418 - accuracy: 0.8508 - val_loss: 0.4431 - val_accuracy: 0.8478
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4380 - accuracy: 0.8512 - val_loss: 0.4407 - val_accuracy: 0.8501
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4347 - accuracy: 0.8527 - val_loss: 0.4364 - val_accuracy: 0.8514
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4316 - accuracy: 0.8530 - val_loss: 0.4344 - val_accuracy: 0.8516
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4289 - accuracy: 0.8538 - val_loss: 0.4311 - val_accuracy: 0.8516
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4266 - accuracy: 0.8541 - val_loss: 0.4295 - val_accuracy: 0.8520
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8353 - accuracy: 0.5881 - val_loss: 0.7828 - val_accuracy: 0.6374
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7039 - accuracy: 0.6708 - val_loss: 0.7011 - val_accuracy: 0.6909
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6511 - accuracy: 0.7246 - val_loss: 0.6509 - val_accuracy: 0.7309
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6191 - accuracy: 0.7571 - val_loss: 0.6273 - val_accuracy: 0.7580
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5941 - accuracy: 0.7765 - val_loss: 0.5793 - val_accuracy: 0.7893
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7910 - val_loss: 0.5639 - val_accuracy: 0.7975
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.8024 - val_loss: 0.5581 - val_accuracy: 0.7934
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.8090 - val_loss: 0.5204 - val_accuracy: 0.8192
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5258 - accuracy: 0.8157 - val_loss: 0.5152 - val_accuracy: 0.8140
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5163 - accuracy: 0.8201 - val_loss: 0.4942 - val_accuracy: 0.8282
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5081 - accuracy: 0.8246 - val_loss: 0.4839 - val_accuracy: 0.8335
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5017 - accuracy: 0.8283 - val_loss: 0.4889 - val_accuracy: 0.8277
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4963 - accuracy: 0.8317 - val_loss: 0.4850 - val_accuracy: 0.8259
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4911 - accuracy: 0.8348 - val_loss: 0.4758 - val_accuracy: 0.8358
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4865 - accuracy: 0.8379 - val_loss: 0.4735 - val_accuracy: 0.8347
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4829 - accuracy: 0.8396 - val_loss: 0.4654 - val_accuracy: 0.8389
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4797 - accuracy: 0.8419 - val_loss: 0.4705 - val_accuracy: 0.8397
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4764 - accuracy: 0.8423 - val_loss: 0.4561 - val_accuracy: 0.8442
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4738 - accuracy: 0.8440 - val_loss: 0.4700 - val_accuracy: 0.8396
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4716 - accuracy: 0.8447 - val_loss: 0.4500 - val_accuracy: 0.8458
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8187 - accuracy: 0.6430 - val_loss: 0.7264 - val_accuracy: 0.7186
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6866 - accuracy: 0.7420 - val_loss: 0.6381 - val_accuracy: 0.7737
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6139 - accuracy: 0.7880 - val_loss: 0.5844 - val_accuracy: 0.8070
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.8099 - val_loss: 0.5479 - val_accuracy: 0.8200
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.8212 - val_loss: 0.5294 - val_accuracy: 0.8133
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5187 - accuracy: 0.8280 - val_loss: 0.5083 - val_accuracy: 0.8287
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5020 - accuracy: 0.8327 - val_loss: 0.4943 - val_accuracy: 0.8293
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4886 - accuracy: 0.8360 - val_loss: 0.4791 - val_accuracy: 0.8416
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4782 - accuracy: 0.8394 - val_loss: 0.4721 - val_accuracy: 0.8376
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4696 - accuracy: 0.8418 - val_loss: 0.4594 - val_accuracy: 0.8486
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4626 - accuracy: 0.8434 - val_loss: 0.4537 - val_accuracy: 0.8518
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4566 - accuracy: 0.8459 - val_loss: 0.4472 - val_accuracy: 0.8522
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4515 - accuracy: 0.8472 - val_loss: 0.4454 - val_accuracy: 0.8518
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4468 - accuracy: 0.8485 - val_loss: 0.4381 - val_accuracy: 0.8544
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4430 - accuracy: 0.8497 - val_loss: 0.4342 - val_accuracy: 0.8574
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4393 - accuracy: 0.8505 - val_loss: 0.4330 - val_accuracy: 0.8564
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4360 - accuracy: 0.8519 - val_loss: 0.4322 - val_accuracy: 0.8550
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4331 - accuracy: 0.8525 - val_loss: 0.4284 - val_accuracy: 0.8549
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4306 - accuracy: 0.8535 - val_loss: 0.4239 - val_accuracy: 0.8588
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4287 - accuracy: 0.8543 - val_loss: 0.4241 - val_accuracy: 0.8596
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8438 - accuracy: 0.5786 - val_loss: 0.7748 - val_accuracy: 0.6286
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7265 - accuracy: 0.6464 - val_loss: 0.7011 - val_accuracy: 0.6878
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6750 - accuracy: 0.6952 - val_loss: 0.6512 - val_accuracy: 0.7481
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6450 - accuracy: 0.7316 - val_loss: 0.6260 - val_accuracy: 0.7560
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6221 - accuracy: 0.7540 - val_loss: 0.6290 - val_accuracy: 0.7463
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6026 - accuracy: 0.7698 - val_loss: 0.5811 - val_accuracy: 0.7925
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5865 - accuracy: 0.7794 - val_loss: 0.5803 - val_accuracy: 0.7802
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5714 - accuracy: 0.7884 - val_loss: 0.5425 - val_accuracy: 0.8093
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5594 - accuracy: 0.7965 - val_loss: 0.5412 - val_accuracy: 0.8068
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.8027 - val_loss: 0.5386 - val_accuracy: 0.8004
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.8078 - val_loss: 0.5215 - val_accuracy: 0.8132
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.8116 - val_loss: 0.5066 - val_accuracy: 0.8214
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5257 - accuracy: 0.8159 - val_loss: 0.5116 - val_accuracy: 0.8189
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5201 - accuracy: 0.8185 - val_loss: 0.4826 - val_accuracy: 0.8327
# Epoch 15/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.5153 - accuracy: 0.8213 - val_loss: 0.4887 - val_accuracy: 0.8290
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5114 - accuracy: 0.8232 - val_loss: 0.5019 - val_accuracy: 0.8224
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5074 - accuracy: 0.8255 - val_loss: 0.4801 - val_accuracy: 0.8333
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5036 - accuracy: 0.8279 - val_loss: 0.4891 - val_accuracy: 0.8314
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5000 - accuracy: 0.8299 - val_loss: 0.4789 - val_accuracy: 0.8338
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4971 - accuracy: 0.8307 - val_loss: 0.4851 - val_accuracy: 0.8305
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8244 - accuracy: 0.6302 - val_loss: 0.7358 - val_accuracy: 0.6828
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6981 - accuracy: 0.7279 - val_loss: 0.6529 - val_accuracy: 0.7710
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6348 - accuracy: 0.7765 - val_loss: 0.6050 - val_accuracy: 0.7901
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5953 - accuracy: 0.7996 - val_loss: 0.5723 - val_accuracy: 0.8134
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5678 - accuracy: 0.8118 - val_loss: 0.5485 - val_accuracy: 0.8157
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.8187 - val_loss: 0.5309 - val_accuracy: 0.8305
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.8243 - val_loss: 0.5153 - val_accuracy: 0.8270
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5163 - accuracy: 0.8287 - val_loss: 0.5044 - val_accuracy: 0.8290
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.8313 - val_loss: 0.4927 - val_accuracy: 0.8346
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4958 - accuracy: 0.8346 - val_loss: 0.4876 - val_accuracy: 0.8327
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4877 - accuracy: 0.8371 - val_loss: 0.4817 - val_accuracy: 0.8352
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4805 - accuracy: 0.8389 - val_loss: 0.4713 - val_accuracy: 0.8422
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4746 - accuracy: 0.8404 - val_loss: 0.4660 - val_accuracy: 0.8421
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4690 - accuracy: 0.8424 - val_loss: 0.4600 - val_accuracy: 0.8465
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4646 - accuracy: 0.8439 - val_loss: 0.4567 - val_accuracy: 0.8504
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4605 - accuracy: 0.8450 - val_loss: 0.4530 - val_accuracy: 0.8476
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4564 - accuracy: 0.8465 - val_loss: 0.4504 - val_accuracy: 0.8475
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4526 - accuracy: 0.8476 - val_loss: 0.4483 - val_accuracy: 0.8514
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4497 - accuracy: 0.8487 - val_loss: 0.4422 - val_accuracy: 0.8503
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4471 - accuracy: 0.8498 - val_loss: 0.4392 - val_accuracy: 0.8516
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8384 - accuracy: 0.5820 - val_loss: 0.7754 - val_accuracy: 0.6353
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7125 - accuracy: 0.6544 - val_loss: 0.7157 - val_accuracy: 0.6626
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6635 - accuracy: 0.7029 - val_loss: 0.6405 - val_accuracy: 0.7558
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.7476 - val_loss: 0.6281 - val_accuracy: 0.7588
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6072 - accuracy: 0.7686 - val_loss: 0.6090 - val_accuracy: 0.7667
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5889 - accuracy: 0.7809 - val_loss: 0.5894 - val_accuracy: 0.7831
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5734 - accuracy: 0.7910 - val_loss: 0.5594 - val_accuracy: 0.8015
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7985 - val_loss: 0.5330 - val_accuracy: 0.8204
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.8047 - val_loss: 0.5344 - val_accuracy: 0.8136
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.8110 - val_loss: 0.5091 - val_accuracy: 0.8295
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.8160 - val_loss: 0.5080 - val_accuracy: 0.8243
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5227 - accuracy: 0.8211 - val_loss: 0.5146 - val_accuracy: 0.8215
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5166 - accuracy: 0.8239 - val_loss: 0.4900 - val_accuracy: 0.8334
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5108 - accuracy: 0.8279 - val_loss: 0.5292 - val_accuracy: 0.8092
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5064 - accuracy: 0.8291 - val_loss: 0.4792 - val_accuracy: 0.8399
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5022 - accuracy: 0.8317 - val_loss: 0.4858 - val_accuracy: 0.8326
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4988 - accuracy: 0.8334 - val_loss: 0.4873 - val_accuracy: 0.8344
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4952 - accuracy: 0.8349 - val_loss: 0.4854 - val_accuracy: 0.8363
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4922 - accuracy: 0.8357 - val_loss: 0.4596 - val_accuracy: 0.8460
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4894 - accuracy: 0.8378 - val_loss: 0.4871 - val_accuracy: 0.8280
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8181 - accuracy: 0.6374 - val_loss: 0.7344 - val_accuracy: 0.6988
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6968 - accuracy: 0.7333 - val_loss: 0.6592 - val_accuracy: 0.7561
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6368 - accuracy: 0.7743 - val_loss: 0.6101 - val_accuracy: 0.7872
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6017 - accuracy: 0.7949 - val_loss: 0.5814 - val_accuracy: 0.8049
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5754 - accuracy: 0.8070 - val_loss: 0.5579 - val_accuracy: 0.8168
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.8161 - val_loss: 0.5376 - val_accuracy: 0.8206
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.8234 - val_loss: 0.5200 - val_accuracy: 0.8312
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5198 - accuracy: 0.8286 - val_loss: 0.5074 - val_accuracy: 0.8284
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.8331 - val_loss: 0.4958 - val_accuracy: 0.8424
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4931 - accuracy: 0.8366 - val_loss: 0.4833 - val_accuracy: 0.8396
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4827 - accuracy: 0.8395 - val_loss: 0.4729 - val_accuracy: 0.8453
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4744 - accuracy: 0.8413 - val_loss: 0.4678 - val_accuracy: 0.8480
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4673 - accuracy: 0.8432 - val_loss: 0.4629 - val_accuracy: 0.8442
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4608 - accuracy: 0.8448 - val_loss: 0.4526 - val_accuracy: 0.8486
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4561 - accuracy: 0.8460 - val_loss: 0.4484 - val_accuracy: 0.8497
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4514 - accuracy: 0.8469 - val_loss: 0.4484 - val_accuracy: 0.8479
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4477 - accuracy: 0.8482 - val_loss: 0.4413 - val_accuracy: 0.8521
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4440 - accuracy: 0.8490 - val_loss: 0.4387 - val_accuracy: 0.8519
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4409 - accuracy: 0.8497 - val_loss: 0.4359 - val_accuracy: 0.8524
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4376 - accuracy: 0.8511 - val_loss: 0.4341 - val_accuracy: 0.8531
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8404 - accuracy: 0.5865 - val_loss: 0.8150 - val_accuracy: 0.6095
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7163 - accuracy: 0.6587 - val_loss: 0.6871 - val_accuracy: 0.6959
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6619 - accuracy: 0.7169 - val_loss: 0.6612 - val_accuracy: 0.7138
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6285 - accuracy: 0.7524 - val_loss: 0.6061 - val_accuracy: 0.7886
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6040 - accuracy: 0.7722 - val_loss: 0.5902 - val_accuracy: 0.7910
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5839 - accuracy: 0.7852 - val_loss: 0.5709 - val_accuracy: 0.7913
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5663 - accuracy: 0.7950 - val_loss: 0.5546 - val_accuracy: 0.8022
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.8032 - val_loss: 0.5247 - val_accuracy: 0.8137
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.8098 - val_loss: 0.5178 - val_accuracy: 0.8218
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5273 - accuracy: 0.8161 - val_loss: 0.5182 - val_accuracy: 0.8149
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5181 - accuracy: 0.8201 - val_loss: 0.5041 - val_accuracy: 0.8217
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5101 - accuracy: 0.8248 - val_loss: 0.4953 - val_accuracy: 0.8271
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5036 - accuracy: 0.8285 - val_loss: 0.4755 - val_accuracy: 0.8370
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4983 - accuracy: 0.8316 - val_loss: 0.4977 - val_accuracy: 0.8261
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4939 - accuracy: 0.8341 - val_loss: 0.4863 - val_accuracy: 0.8331
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4902 - accuracy: 0.8355 - val_loss: 0.4635 - val_accuracy: 0.8426
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4866 - accuracy: 0.8380 - val_loss: 0.4601 - val_accuracy: 0.8451
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4835 - accuracy: 0.8390 - val_loss: 0.4690 - val_accuracy: 0.8378
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4804 - accuracy: 0.8397 - val_loss: 0.4676 - val_accuracy: 0.8386
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4777 - accuracy: 0.8415 - val_loss: 0.4609 - val_accuracy: 0.8426
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8079 - accuracy: 0.6433 - val_loss: 0.7177 - val_accuracy: 0.7140
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6686 - accuracy: 0.7557 - val_loss: 0.6320 - val_accuracy: 0.7728
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6035 - accuracy: 0.7965 - val_loss: 0.5898 - val_accuracy: 0.8041
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5659 - accuracy: 0.8135 - val_loss: 0.5566 - val_accuracy: 0.8053
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.8234 - val_loss: 0.5414 - val_accuracy: 0.8321
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5196 - accuracy: 0.8295 - val_loss: 0.5160 - val_accuracy: 0.8258
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5035 - accuracy: 0.8339 - val_loss: 0.4967 - val_accuracy: 0.8338
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4903 - accuracy: 0.8372 - val_loss: 0.4841 - val_accuracy: 0.8386
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4799 - accuracy: 0.8401 - val_loss: 0.4769 - val_accuracy: 0.8394
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4712 - accuracy: 0.8420 - val_loss: 0.4663 - val_accuracy: 0.8427
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4638 - accuracy: 0.8444 - val_loss: 0.4610 - val_accuracy: 0.8428
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4575 - accuracy: 0.8459 - val_loss: 0.4542 - val_accuracy: 0.8491
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4520 - accuracy: 0.8470 - val_loss: 0.4491 - val_accuracy: 0.8463
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4470 - accuracy: 0.8485 - val_loss: 0.4457 - val_accuracy: 0.8478
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4426 - accuracy: 0.8498 - val_loss: 0.4396 - val_accuracy: 0.8499
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4388 - accuracy: 0.8500 - val_loss: 0.4361 - val_accuracy: 0.8497
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4356 - accuracy: 0.8507 - val_loss: 0.4335 - val_accuracy: 0.8501
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4329 - accuracy: 0.8515 - val_loss: 0.4330 - val_accuracy: 0.8524
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4301 - accuracy: 0.8521 - val_loss: 0.4272 - val_accuracy: 0.8537
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4277 - accuracy: 0.8525 - val_loss: 0.4294 - val_accuracy: 0.8550
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8476 - accuracy: 0.5807 - val_loss: 0.7873 - val_accuracy: 0.6262
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7215 - accuracy: 0.6511 - val_loss: 0.7229 - val_accuracy: 0.6744
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6722 - accuracy: 0.6951 - val_loss: 0.6900 - val_accuracy: 0.7071
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6439 - accuracy: 0.7311 - val_loss: 0.6405 - val_accuracy: 0.7545
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6218 - accuracy: 0.7553 - val_loss: 0.6051 - val_accuracy: 0.7753
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6034 - accuracy: 0.7690 - val_loss: 0.5903 - val_accuracy: 0.7873
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5868 - accuracy: 0.7805 - val_loss: 0.5665 - val_accuracy: 0.8072
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7890 - val_loss: 0.5749 - val_accuracy: 0.7866
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7963 - val_loss: 0.5466 - val_accuracy: 0.8076
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.8019 - val_loss: 0.5290 - val_accuracy: 0.8120
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.8075 - val_loss: 0.5197 - val_accuracy: 0.8212
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.8119 - val_loss: 0.5187 - val_accuracy: 0.8133
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5269 - accuracy: 0.8151 - val_loss: 0.5008 - val_accuracy: 0.8258
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5216 - accuracy: 0.8185 - val_loss: 0.5024 - val_accuracy: 0.8231
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5162 - accuracy: 0.8211 - val_loss: 0.5094 - val_accuracy: 0.8162
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5113 - accuracy: 0.8231 - val_loss: 0.4744 - val_accuracy: 0.8402
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5074 - accuracy: 0.8254 - val_loss: 0.4957 - val_accuracy: 0.8256
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5035 - accuracy: 0.8277 - val_loss: 0.4850 - val_accuracy: 0.8304
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5004 - accuracy: 0.8288 - val_loss: 0.4725 - val_accuracy: 0.8382
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4965 - accuracy: 0.8311 - val_loss: 0.4777 - val_accuracy: 0.8345
# Epoch 1/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.8203 - accuracy: 0.6358 - val_loss: 0.7471 - val_accuracy: 0.6729
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7053 - accuracy: 0.7223 - val_loss: 0.6705 - val_accuracy: 0.7588
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6487 - accuracy: 0.7619 - val_loss: 0.6334 - val_accuracy: 0.7659
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6138 - accuracy: 0.7867 - val_loss: 0.5951 - val_accuracy: 0.7991
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5851 - accuracy: 0.8032 - val_loss: 0.5704 - val_accuracy: 0.8057
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5612 - accuracy: 0.8144 - val_loss: 0.5466 - val_accuracy: 0.8226
# Epoch 7/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.8223 - val_loss: 0.5279 - val_accuracy: 0.8261
# Epoch 8/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5231 - accuracy: 0.8275 - val_loss: 0.5112 - val_accuracy: 0.8349
# Epoch 9/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5094 - accuracy: 0.8312 - val_loss: 0.5013 - val_accuracy: 0.8360
# Epoch 10/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.4979 - accuracy: 0.8338 - val_loss: 0.4882 - val_accuracy: 0.8402
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4883 - accuracy: 0.8363 - val_loss: 0.4798 - val_accuracy: 0.8398
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4802 - accuracy: 0.8383 - val_loss: 0.4730 - val_accuracy: 0.8441
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4738 - accuracy: 0.8400 - val_loss: 0.4680 - val_accuracy: 0.8417
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4682 - accuracy: 0.8418 - val_loss: 0.4636 - val_accuracy: 0.8494
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4632 - accuracy: 0.8432 - val_loss: 0.4585 - val_accuracy: 0.8432
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4587 - accuracy: 0.8446 - val_loss: 0.4535 - val_accuracy: 0.8473
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4549 - accuracy: 0.8456 - val_loss: 0.4489 - val_accuracy: 0.8491
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4515 - accuracy: 0.8471 - val_loss: 0.4490 - val_accuracy: 0.8462
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4478 - accuracy: 0.8481 - val_loss: 0.4417 - val_accuracy: 0.8512
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4450 - accuracy: 0.8493 - val_loss: 0.4411 - val_accuracy: 0.8536
# Epoch 1/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.8416 - accuracy: 0.5879 - val_loss: 0.7736 - val_accuracy: 0.6349
# Epoch 2/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.7151 - accuracy: 0.6558 - val_loss: 0.7009 - val_accuracy: 0.6781
# Epoch 3/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6615 - accuracy: 0.7084 - val_loss: 0.6603 - val_accuracy: 0.7253
# Epoch 4/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6284 - accuracy: 0.7474 - val_loss: 0.6277 - val_accuracy: 0.7512
# Epoch 5/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.6035 - accuracy: 0.7674 - val_loss: 0.5773 - val_accuracy: 0.7930
# Epoch 6/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5836 - accuracy: 0.7813 - val_loss: 0.5964 - val_accuracy: 0.7666
# Epoch 7/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.5667 - accuracy: 0.7910 - val_loss: 0.5569 - val_accuracy: 0.7997
# Epoch 8/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.5531 - accuracy: 0.7976 - val_loss: 0.5459 - val_accuracy: 0.8004
# Epoch 9/20
# 1155/1155 [==============================] - 3s 2ms/step - loss: 0.5413 - accuracy: 0.8048 - val_loss: 0.5330 - val_accuracy: 0.8050
# Epoch 10/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.8092 - val_loss: 0.5123 - val_accuracy: 0.8196
# Epoch 11/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5243 - accuracy: 0.8135 - val_loss: 0.5107 - val_accuracy: 0.8196
# Epoch 12/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5180 - accuracy: 0.8174 - val_loss: 0.4899 - val_accuracy: 0.8334
# Epoch 13/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5124 - accuracy: 0.8208 - val_loss: 0.5062 - val_accuracy: 0.8196
# Epoch 14/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5073 - accuracy: 0.8235 - val_loss: 0.4738 - val_accuracy: 0.8396
# Epoch 15/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.5027 - accuracy: 0.8266 - val_loss: 0.4987 - val_accuracy: 0.8232
# Epoch 16/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4985 - accuracy: 0.8291 - val_loss: 0.4725 - val_accuracy: 0.8392
# Epoch 17/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.8312 - val_loss: 0.4527 - val_accuracy: 0.8476
# Epoch 18/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4913 - accuracy: 0.8339 - val_loss: 0.4713 - val_accuracy: 0.8409
# Epoch 19/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4884 - accuracy: 0.8352 - val_loss: 0.4640 - val_accuracy: 0.8436
# Epoch 20/20
# 1155/1155 [==============================] - 2s 2ms/step - loss: 0.4855 - accuracy: 0.8376 - val_loss: 0.4581 - val_accuracy: 0.8454

# %%
epochs = np.linspace(0,19,20)

train_acc_mean = np.average(np.vstack(train_acc), axis = 0)
train_loss_mean = np.average(np.vstack(train_loss), axis = 0)
train_acc_std = np.std(np.vstack(train_acc), axis = 0)
train_loss_std = np.std(np.vstack(train_loss), axis = 0)

val_acc_mean = np.average(np.vstack(val_acc), axis = 0)
val_loss_mean = np.average(np.vstack(val_loss), axis = 0)
val_acc_std = np.std(np.vstack(val_acc), axis = 0)
val_loss_std = np.std(np.vstack(val_loss), axis = 0)

#--------------------------------------------------------------#

train_acc_meanw = np.average(np.vstack(train_accw), axis = 0)
train_loss_meanw = np.average(np.vstack(train_lossw), axis = 0)
train_acc_stdw = np.std(np.vstack(train_accw), axis = 0)
train_loss_stdw = np.std(np.vstack(train_lossw), axis = 0)

val_acc_meanw = np.average(np.vstack(val_accw), axis = 0)
val_loss_meanw = np.average(np.vstack(val_lossw), axis = 0)
val_acc_stdw = np.std(np.vstack(val_accw), axis = 0)
val_loss_stdw = np.std(np.vstack(val_lossw), axis = 0)

# %%
plt.plot(train_acc_mean, label = r'Train Accuracy', color = 'C0')
plt.fill_between(epochs, train_acc_mean - train_acc_std, train_acc_mean + train_acc_std, color = 'C0', alpha = 0.6)
plt.plot(val_acc_mean, label = r'Val Accuracy', color = 'C1')
plt.fill_between(epochs, val_acc_mean - val_acc_std, val_acc_mean + val_acc_std, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Accuracy')
plt.legend()

# %%
plt.plot(train_acc_meanw, label = r'Weighted train Accuracy', color = 'C0')
plt.fill_between(epochs, train_acc_meanw - train_acc_stdw, train_acc_meanw + train_acc_stdw, color = 'C0', alpha = 0.6)
plt.plot(val_acc_meanw, label = r'Weighted val Accuracy', color = 'C1')
plt.fill_between(epochs, val_acc_meanw - val_acc_stdw, val_acc_meanw + val_acc_stdw, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Accuracy')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(train_acc_mean, label = r'Train Accuracy', color = 'C0')
ax1.fill_between(epochs, train_acc_mean - train_acc_std, train_acc_mean + train_acc_std, color = 'C0', alpha = 0.6)
ax1.plot(val_acc_mean, label = r'Val Accuracy', color = 'C1')
ax1.fill_between(epochs, val_acc_mean - val_acc_std, val_acc_mean + val_acc_std, color = 'C1', alpha = 0.6)
ax1.set_xlabel(r'Épocas')
ax1.set_ylabel(r'Accuracy')
ax1.legend()

#plt.subplot(1,2,2)
ax2.plot(train_acc_meanw, label = r'Weighted train Accuracy', color = 'C0')
ax2.fill_between(epochs, train_acc_meanw - train_acc_stdw, train_acc_meanw + train_acc_stdw, color = 'C0', alpha = 0.6)
ax2.plot(val_acc_meanw, label = r'Weighted val Accuracy', color = 'C1')
ax2.fill_between(epochs, val_acc_meanw - val_acc_stdw, val_acc_meanw + val_acc_stdw, color = 'C1', alpha = 0.6)
ax2.set_xlabel(r'Épocas')
ax2.set_ylabel(r'Accuracy')
ax2.legend()

# %%
plt.plot(train_loss_mean, label = r'Train Loss', color = 'C0')
plt.fill_between(epochs, train_loss_mean - train_loss_std, train_loss_mean + train_loss_std, color = 'C0', alpha = 0.6)
plt.plot(val_loss_mean, label = r'Val Loss', color = 'C1')
plt.fill_between(epochs, val_loss_mean - val_loss_std, val_loss_mean + val_loss_std, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Loss')
plt.legend()

# %%
plt.plot(train_loss_meanw, label = r'Weighted train Loss', color = 'C0')
plt.fill_between(epochs, train_loss_meanw - train_loss_stdw, train_loss_meanw + train_loss_stdw, color = 'C0', alpha = 0.6)
plt.plot(val_loss_meanw, label = r'Weighted val Loss', color = 'C1')
plt.fill_between(epochs, val_loss_meanw - val_loss_stdw, val_loss_meanw + val_loss_stdw, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Loss')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(train_loss_mean, label = r'Train Loss', color = 'C0')
ax1.fill_between(epochs, train_loss_mean - train_loss_std, train_loss_mean + train_loss_std, color = 'C0', alpha = 0.6)
ax1.plot(val_loss_mean, label = r'Val Loss', color = 'C1')
ax1.fill_between(epochs, val_loss_mean - val_loss_std, val_loss_mean + val_loss_std, color = 'C1', alpha = 0.6)
ax1.set_xlabel(r'Épocas')
ax1.set_ylabel(r'Loss')
ax1.legend()

#--------------------------------------------------------------#

ax2.plot(train_loss_meanw, label = r'Weighted train Loss', color = 'C0')
ax2.fill_between(epochs, train_loss_meanw - train_loss_stdw, train_loss_meanw + train_loss_stdw, color = 'C0', alpha = 0.6)
ax2.plot(val_loss_meanw, label = r'Weighted val Loss', color = 'C1')
ax2.fill_between(epochs, val_loss_meanw - val_loss_stdw, val_loss_meanw + val_loss_stdw, color = 'C1', alpha = 0.6)
ax2.set_xlabel(r'Épocas')
ax2.set_ylabel(r'Loss')
ax2.legend()

# %%
precisions = []
precisiong = []
precisionq = []

recalls = []
recallg = []
recallq = []

for i in range(10):
  precisions.append(np.array(precision)[i][0])
  precisiong.append(np.array(precision)[i][1])
  precisionq.append(np.array(precision)[i][2])
  recalls.append(np.array(recall)[i][0])
  recallg.append(np.array(recall)[i][1])
  recallq.append(np.array(recall)[i][2])

#--------------------------------------------------------------#

precisionsw = []
precisiongw = []
precisionqw = []

recallsw = []
recallgw = []
recallqw = []

for i in range(10):
  precisionsw.append(np.array(precisionw)[i][0])
  precisiongw.append(np.array(precisionw)[i][1])
  precisionqw.append(np.array(precisionw)[i][2])
  recallsw.append(np.array(recallw)[i][0])
  recallgw.append(np.array(recallw)[i][1])
  recallqw.append(np.array(recallw)[i][2])

# %%
plt.plot(np.average(np.vstack(recalls), axis = 0),np.average(np.vstack(precisions), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls), axis = 0), np.average(np.vstack(precisions), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(recallg), axis = 0),np.average(np.vstack(precisiong), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg), axis = 0), np.average(np.vstack(precisiong), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(recallq), axis = 0),np.average(np.vstack(precisionq), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recallq), axis = 0), np.average(np.vstack(precisionq), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(recalls), axis = 0), np.std(np.vstack(precisions), axis = 0) + np.average(np.vstack(precisions), axis = 0), - np.std(np.vstack(precisions), axis = 0) + np.average(np.vstack(precisions), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallg), axis = 0), np.std(np.vstack(precisiong), axis = 0) + np.average(np.vstack(precisiong), axis = 0), - np.std(np.vstack(precisiong), axis = 0) + np.average(np.vstack(precisiong), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallq), axis = 0), np.std(np.vstack(precisionq), axis = 0) + np.average(np.vstack(precisionq), axis = 0), - np.std(np.vstack(precisionq), axis = 0) + np.average(np.vstack(precisionq), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
plt.plot(np.average(np.vstack(recallsw), axis = 0),np.average(np.vstack(precisionsw), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recallsw), axis = 0), np.average(np.vstack(precisionsw), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(recallgw), axis = 0),np.average(np.vstack(precisiongw), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallgw), axis = 0), np.average(np.vstack(precisiongw), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(recallqw), axis = 0),np.average(np.vstack(precisionqw), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallqw), axis = 0), np.average(np.vstack(precisionqw), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(recallsw), axis = 0), np.std(np.vstack(precisionsw), axis = 0) + np.average(np.vstack(precisionsw), axis = 0), - np.std(np.vstack(precisionsw), axis = 0) + np.average(np.vstack(precisionsw), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallgw), axis = 0), np.std(np.vstack(precisiongw), axis = 0) + np.average(np.vstack(precisiongw), axis = 0), - np.std(np.vstack(precisiongw), axis = 0) + np.average(np.vstack(precisiongw), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallqw), axis = 0), np.std(np.vstack(precisionqw), axis = 0) + np.average(np.vstack(precisionqw), axis = 0), - np.std(np.vstack(precisionqw), axis = 0) + np.average(np.vstack(precisionqw), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(np.average(np.vstack(recalls), axis = 0),np.average(np.vstack(precisions), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls), axis = 0), np.average(np.vstack(precisions), axis = 0)), color = 'C0')
ax1.plot(np.average(np.vstack(recallg), axis = 0),np.average(np.vstack(precisiong), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg), axis = 0), np.average(np.vstack(precisiong), axis = 0)), color = 'C1')
ax1.plot(np.average(np.vstack(recallq), axis = 0),np.average(np.vstack(precisionq), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallq), axis = 0), np.average(np.vstack(precisionq), axis = 0)), color = 'C2')
ax1.fill_between(np.average(np.vstack(recalls), axis = 0), np.std(np.vstack(precisions), axis = 0) + np.average(np.vstack(precisions), axis = 0), - np.std(np.vstack(precisions), axis = 0) + np.average(np.vstack(precisions), axis = 0), color = 'C0', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(recallg), axis = 0), np.std(np.vstack(precisiong), axis = 0) + np.average(np.vstack(precisiong), axis = 0), - np.std(np.vstack(precisiong), axis = 0) + np.average(np.vstack(precisiong), axis = 0), color = 'C1', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(recallq), axis = 0), np.std(np.vstack(precisionq), axis = 0) + np.average(np.vstack(precisionq), axis = 0), - np.std(np.vstack(precisionq), axis = 0) + np.average(np.vstack(precisionq), axis = 0), color = 'C2', alpha = 0.5)

ax1.set_xlabel(r'Recall')
ax1.set_ylabel(r'Precision')
ax1.set_title(r'Baseline')
ax1.legend()

ax2.plot(np.average(np.vstack(recallsw), axis = 0),np.average(np.vstack(precisionsw), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recallsw), axis = 0), np.average(np.vstack(precisionsw), axis = 0)), color = 'C0')
ax2.plot(np.average(np.vstack(recallgw), axis = 0),np.average(np.vstack(precisiongw), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallgw), axis = 0), np.average(np.vstack(precisiongw), axis = 0)), color = 'C1')
ax2.plot(np.average(np.vstack(recallqw), axis = 0),np.average(np.vstack(precisionqw), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallqw), axis = 0), np.average(np.vstack(precisionqw), axis = 0)), color = 'C2')
ax2.fill_between(np.average(np.vstack(recallsw), axis = 0), np.std(np.vstack(precisionsw), axis = 0) + np.average(np.vstack(precisionsw), axis = 0), - np.std(np.vstack(precisionsw), axis = 0) + np.average(np.vstack(precisionsw), axis = 0), color = 'C0', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(recallgw), axis = 0), np.std(np.vstack(precisiongw), axis = 0) + np.average(np.vstack(precisiongw), axis = 0), - np.std(np.vstack(precisiongw), axis = 0) + np.average(np.vstack(precisiongw), axis = 0), color = 'C1', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(recallqw), axis = 0), np.std(np.vstack(precisionqw), axis = 0) + np.average(np.vstack(precisionqw), axis = 0), - np.std(np.vstack(precisionqw), axis = 0) + np.average(np.vstack(precisionqw), axis = 0), color = 'C2', alpha = 0.5)

ax2.set_xlabel(r'Recall')
ax2.set_ylabel(r'Precision')
ax2.set_title(r'Weighted')
ax2.legend()

# %%
tprs = []
tprg = []
tprq = []

fprs = []
fprg = []
fprq = []

for i in range(10):
  tprs.append(np.array(tpr)[i][0])
  tprg.append(np.array(tpr)[i][1])
  tprq.append(np.array(tpr)[i][2])
  fprs.append(np.array(fpr)[i][0])
  fprg.append(np.array(fpr)[i][1])
  fprq.append(np.array(fpr)[i][2])

#-----------------------------------------------------------#

tprsw = []
tprgw = []
tprqw = []

fprsw = []
fprgw = []
fprqw = []

for i in range(10):
  tprsw.append(np.array(tprw)[i][0])
  tprgw.append(np.array(tprw)[i][1])
  tprqw.append(np.array(tprw)[i][2])
  fprsw.append(np.array(fprw)[i][0])
  fprgw.append(np.array(fprw)[i][1])
  fprqw.append(np.array(fprw)[i][2])

# %%
plt.plot(np.average(np.vstack(fprs), axis = 0),np.average(np.vstack(tprs), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs), axis = 0), np.average(np.vstack(tprs), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(fprg), axis = 0),np.average(np.vstack(tprg), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg), axis = 0), np.average(np.vstack(tprg), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(fprq), axis = 0),np.average(np.vstack(tprq), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq), axis = 0), np.average(np.vstack(tprq), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(fprs), axis = 0), np.std(np.vstack(tprs), axis = 0) + np.average(np.vstack(tprs), axis = 0), - np.std(np.vstack(tprs), axis = 0) + np.average(np.vstack(tprs), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprg), axis = 0), np.std(np.vstack(tprg), axis = 0) + np.average(np.vstack(tprg), axis = 0), - np.std(np.vstack(tprg), axis = 0) + np.average(np.vstack(tprg), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprq), axis = 0), np.std(np.vstack(tprq), axis = 0) + np.average(np.vstack(tprq), axis = 0), - np.std(np.vstack(tprq), axis = 0) + np.average(np.vstack(tprq), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'TPR')
plt.ylabel(r'FPR')
plt.legend()

# %%
plt.plot(np.average(np.vstack(fprsw), axis = 0),np.average(np.vstack(tprsw), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprsw), axis = 0), np.average(np.vstack(tprsw), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(fprgw), axis = 0),np.average(np.vstack(tprgw), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprgw), axis = 0), np.average(np.vstack(tprgw), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(fprqw), axis = 0),np.average(np.vstack(tprqw), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprqw), axis = 0), np.average(np.vstack(tprqw), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(fprsw), axis = 0), np.std(np.vstack(tprsw), axis = 0) + np.average(np.vstack(tprsw), axis = 0), - np.std(np.vstack(tprsw), axis = 0) + np.average(np.vstack(tprsw), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprgw), axis = 0), np.std(np.vstack(tprgw), axis = 0) + np.average(np.vstack(tprgw), axis = 0), - np.std(np.vstack(tprgw), axis = 0) + np.average(np.vstack(tprgw), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprqw), axis = 0), np.std(np.vstack(tprqw), axis = 0) + np.average(np.vstack(tprqw), axis = 0), - np.std(np.vstack(tprqw), axis = 0) + np.average(np.vstack(tprqw), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'TPR')
plt.ylabel(r'FPR')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(np.average(np.vstack(fprs), axis = 0),np.average(np.vstack(tprs), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs), axis = 0), np.average(np.vstack(tprs), axis = 0)), color = 'C0')
ax1.plot(np.average(np.vstack(fprg), axis = 0),np.average(np.vstack(tprg), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg), axis = 0), np.average(np.vstack(tprg), axis = 0)), color = 'C1')
ax1.plot(np.average(np.vstack(fprq), axis = 0),np.average(np.vstack(tprq), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq), axis = 0), np.average(np.vstack(tprq), axis = 0)), color = 'C2')
ax1.fill_between(np.average(np.vstack(fprs), axis = 0), np.std(np.vstack(tprs), axis = 0) + np.average(np.vstack(tprs), axis = 0), - np.std(np.vstack(tprs), axis = 0) + np.average(np.vstack(tprs), axis = 0), color = 'C0', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(fprg), axis = 0), np.std(np.vstack(tprg), axis = 0) + np.average(np.vstack(tprg), axis = 0), - np.std(np.vstack(tprg), axis = 0) + np.average(np.vstack(tprg), axis = 0), color = 'C1', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(fprq), axis = 0), np.std(np.vstack(tprq), axis = 0) + np.average(np.vstack(tprq), axis = 0), - np.std(np.vstack(tprq), axis = 0) + np.average(np.vstack(tprq), axis = 0), color = 'C2', alpha = 0.5)

ax1.set_xlabel(r'TPR')
ax1.set_ylabel(r'FPR')
ax1.set_title(r'Baseline')
ax1.legend()

ax2.plot(np.average(np.vstack(fprsw), axis = 0),np.average(np.vstack(tprsw), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprsw), axis = 0), np.average(np.vstack(tprsw), axis = 0)), color = 'C0')
ax2.plot(np.average(np.vstack(fprgw), axis = 0),np.average(np.vstack(tprgw), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprgw), axis = 0), np.average(np.vstack(tprgw), axis = 0)), color = 'C1')
ax2.plot(np.average(np.vstack(fprqw), axis = 0),np.average(np.vstack(tprqw), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprqw), axis = 0), np.average(np.vstack(tprqw), axis = 0)), color = 'C2')
ax2.fill_between(np.average(np.vstack(fprsw), axis = 0), np.std(np.vstack(tprsw), axis = 0) + np.average(np.vstack(tprsw), axis = 0), - np.std(np.vstack(tprsw), axis = 0) + np.average(np.vstack(tprsw), axis = 0), color = 'C0', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(fprgw), axis = 0), np.std(np.vstack(tprgw), axis = 0) + np.average(np.vstack(tprgw), axis = 0), - np.std(np.vstack(tprgw), axis = 0) + np.average(np.vstack(tprgw), axis = 0), color = 'C1', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(fprqw), axis = 0), np.std(np.vstack(tprqw), axis = 0) + np.average(np.vstack(tprqw), axis = 0), - np.std(np.vstack(tprqw), axis = 0) + np.average(np.vstack(tprqw), axis = 0), color = 'C2', alpha = 0.5)

ax2.set_xlabel(r'TPR')
ax2.set_ylabel(r'FPR')
ax2.set_title(r'Weighted')
ax2.legend()

# %%
labels = ['STAR', 'GALAXY', 'QSO']

# %%
cmatrix = confusion_matrix(np.array(y_test), np.argmax(test_pred, axis = 1))
cmatrix
# Out:
# array([[ 8835,   974,  1058],
#        [  281, 17701,   643],
#        [  543,  1909,  4987]])

# %%
cmatrixw = confusion_matrix(np.array(y_testw), np.argmax(test_predw, axis = 1))
cmatrixw
# Out:
# array([[ 8962,   703,  1202],
#        [  630, 16472,  1523],
#        [  470,  1180,  5789]])

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

sns.heatmap(cmatrix, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10', ax = ax1)
ax1.set_title(r'Baseline')
sns.heatmap(cmatrixw, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10', ax = ax2)
ax2.set_title(r'Weighted')
# Out:
# Text(0.5, 1.0, 'Weighted')

# %%
y_test.value_counts()
# Out:
# 1    18625
# 0    10867
# 2     7439
# Name: class, dtype: int64

# %%
report = classification_report(y_test, np.argmax(test_pred, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
report = pd.DataFrame(report)
report.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
report
# Out:
#                Star    Galaxy       QSO
# precision  0.914691  0.859940  0.745664
# recall     0.813012  0.950389  0.670386
# f1-score   0.860859  0.902905  0.706024

# %%
reportw = classification_report(y_testw, np.argmax(test_predw, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
reportw = pd.DataFrame(reportw)
reportw.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
reportw
# Out:
#                Star    Galaxy       QSO
# precision  0.890678  0.897412  0.679939
# recall     0.824699  0.884403  0.778196
# f1-score   0.856419  0.890860  0.725757

# %% [markdown]
# ---
# Agora a rede convolucional mais profunda
#
#
# ---
#
#
#
# ---

# %%
folds = 10
n_classes = 3

train_acc2 = []
train_loss2 = []

val_acc2 = []
val_loss2 = []

# For each class
precision2 = [{}]*folds
recall2 = [{}]*folds
average_precision2 = [{}]*folds

fpr2 = [{}]*folds
tpr2 = [{}]*folds
roc_auc2 = [{}]*folds

train_acc2w = []
train_loss2w = []

val_acc2w = []
val_loss2w = []

# For each class
precision2w = [{}]*folds
recall2w = [{}]*folds
average_precision2w = [{}]*folds

fpr2w = [{}]*folds
tpr2w = [{}]*folds
roc_auc2w = [{}]*folds


for i in range(folds):
  x_train2, x_test2, y_train2, y_test2 = train_test_split(xconv, y, test_size = 0.2, random_state = i) 

  model2 = Sequential()

  model2.add(Conv1D(32, 2, activation = 'relu', input_shape = (8, 1)))
  model2.add(Dropout(0.2))
  model2.add(MaxPooling1D(2))
  model2.add(Conv1D(32,2, activation = 'relu'))
  model2.add(Dropout(0.15))
  model2.add(MaxPooling1D(2))
  model2.add(Conv1D(16,1, activation = 'relu'))
  model2.add(Dropout(0.15))
  model2.add(Flatten())
  model2.add(Dense(3, activation = 'softmax'))

  model2.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
  

  history2 = model2.fit(
    x_train2,
    to_categorical(y_train2),
    epochs = 20,
    batch_size = 128,
    validation_data = (
        x_test2,
        to_categorical(y_test2)
    )
)
  
  test_pred2 = model.predict(x_test2)
  
  train_acc2.append(history2.history['accuracy'])
  train_loss2.append(history2.history['loss'])

  val_acc2.append(history2.history['val_accuracy'])
  val_loss2.append(history2.history['val_loss'])

#------------------------------------------------------------------------------#

  x_train2w, x_test2w, y_train2w, y_test2w = train_test_split(xconv, y, test_size = 0.2, random_state = i) 

  class_weights = class_weight.compute_class_weight(
    'balanced',
    np.unique(y_train2w),
    y_train2w
  )
  class_weights = {i  :class_weights[i] for i in range(3)}

  model2w = Sequential()

  model2w.add(Conv1D(32, 2, activation = 'relu', input_shape = (8, 1)))
  model2w.add(Dropout(0.2))
  model2w.add(MaxPooling1D(2))
  model2w.add(Conv1D(32,2, activation = 'relu'))
  model2w.add(Dropout(0.15))
  model2w.add(MaxPooling1D(2))
  model2w.add(Conv1D(16,1, activation = 'relu'))
  model2w.add(Dropout(0.15))
  model2w.add(Flatten())
  model2w.add(Dense(3, activation = 'softmax'))

  model2w.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
  

  history2w = model2w.fit(
    x_train2,
    to_categorical(y_train2),
    epochs = 20,
    batch_size = 128,
    validation_data = (
        x_test2,
        to_categorical(y_test2)),
        class_weight = class_weights
)
  
  test_pred2w = model2w.predict(x_test2w)
  
  train_acc2w.append(history2w.history['accuracy'])
  train_loss2w.append(history2w.history['loss'])

  val_acc2w.append(history2w.history['val_accuracy'])
  val_loss2w.append(history2w.history['val_loss'])

  for j in range(n_classes):
      precision2[i][j], recall2[i][j], _ = precision_recall_curve(to_categorical(np.array(y_test2))[:, j],test_pred2[:, j])
      precision2w[i][j], recall2w[i][j], _ = precision_recall_curve(to_categorical(np.array(y_test2w))[:, j],test_pred2w[:, j])

  for j in range(n_classes):
    fpr2[i][j], tpr2[i][j], _ = roc_curve(to_categorical(np.array(y_test2))[:,j], test_pred2[:,j])
    fpr2w[i][j], tpr2w[i][j], _ = roc_curve(to_categorical(np.array(y_test2w))[:,j], test_pred2w[:,j])
# Out:
# Epoch 1/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.8199 - accuracy: 0.6153 - val_loss: 0.7020 - val_accuracy: 0.6837
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.6701 - accuracy: 0.7300 - val_loss: 0.5718 - val_accuracy: 0.8234
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5845 - accuracy: 0.7808 - val_loss: 0.4959 - val_accuracy: 0.8272
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5318 - accuracy: 0.8078 - val_loss: 0.4500 - val_accuracy: 0.8459
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5020 - accuracy: 0.8214 - val_loss: 0.4369 - val_accuracy: 0.8486
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4845 - accuracy: 0.8289 - val_loss: 0.4217 - val_accuracy: 0.8535
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4719 - accuracy: 0.8342 - val_loss: 0.4145 - val_accuracy: 0.8558
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4654 - accuracy: 0.8364 - val_loss: 0.4390 - val_accuracy: 0.8450
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4580 - accuracy: 0.8398 - val_loss: 0.4043 - val_accuracy: 0.8591
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4537 - accuracy: 0.8416 - val_loss: 0.4041 - val_accuracy: 0.8583
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4500 - accuracy: 0.8426 - val_loss: 0.3952 - val_accuracy: 0.8618
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4473 - accuracy: 0.8428 - val_loss: 0.3951 - val_accuracy: 0.8590
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4447 - accuracy: 0.8443 - val_loss: 0.3946 - val_accuracy: 0.8632
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4414 - accuracy: 0.8453 - val_loss: 0.3892 - val_accuracy: 0.8630
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4381 - accuracy: 0.8475 - val_loss: 0.3887 - val_accuracy: 0.8648
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4389 - accuracy: 0.8470 - val_loss: 0.3861 - val_accuracy: 0.8644
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4361 - accuracy: 0.8471 - val_loss: 0.3865 - val_accuracy: 0.8659
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4344 - accuracy: 0.8477 - val_loss: 0.3831 - val_accuracy: 0.8657
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4326 - accuracy: 0.8482 - val_loss: 0.4050 - val_accuracy: 0.8547
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4321 - accuracy: 0.8483 - val_loss: 0.3872 - val_accuracy: 0.8640
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8058 - accuracy: 0.6277 - val_loss: 0.6395 - val_accuracy: 0.7509
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6099 - accuracy: 0.7759 - val_loss: 0.4926 - val_accuracy: 0.8287
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5532 - accuracy: 0.8043 - val_loss: 0.4536 - val_accuracy: 0.8411
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5320 - accuracy: 0.8135 - val_loss: 0.4595 - val_accuracy: 0.8384
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5199 - accuracy: 0.8195 - val_loss: 0.4511 - val_accuracy: 0.8389
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5082 - accuracy: 0.8243 - val_loss: 0.4203 - val_accuracy: 0.8575
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5023 - accuracy: 0.8277 - val_loss: 0.4275 - val_accuracy: 0.8544
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4962 - accuracy: 0.8309 - val_loss: 0.4276 - val_accuracy: 0.8548
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4922 - accuracy: 0.8322 - val_loss: 0.4216 - val_accuracy: 0.8567
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4875 - accuracy: 0.8352 - val_loss: 0.4318 - val_accuracy: 0.8511
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4870 - accuracy: 0.8356 - val_loss: 0.4102 - val_accuracy: 0.8592
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4811 - accuracy: 0.8368 - val_loss: 0.4117 - val_accuracy: 0.8573
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4802 - accuracy: 0.8375 - val_loss: 0.4141 - val_accuracy: 0.8553
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4772 - accuracy: 0.8388 - val_loss: 0.4194 - val_accuracy: 0.8503
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4761 - accuracy: 0.8405 - val_loss: 0.4144 - val_accuracy: 0.8540
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4735 - accuracy: 0.8413 - val_loss: 0.3995 - val_accuracy: 0.8631
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4718 - accuracy: 0.8416 - val_loss: 0.3993 - val_accuracy: 0.8603
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4707 - accuracy: 0.8422 - val_loss: 0.4229 - val_accuracy: 0.8524
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4681 - accuracy: 0.8427 - val_loss: 0.4076 - val_accuracy: 0.8616
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4670 - accuracy: 0.8426 - val_loss: 0.4002 - val_accuracy: 0.8623
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.7989 - accuracy: 0.6486 - val_loss: 0.6024 - val_accuracy: 0.7982
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5719 - accuracy: 0.7924 - val_loss: 0.4694 - val_accuracy: 0.8379
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5099 - accuracy: 0.8178 - val_loss: 0.4611 - val_accuracy: 0.8301
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4891 - accuracy: 0.8261 - val_loss: 0.4344 - val_accuracy: 0.8484
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4791 - accuracy: 0.8304 - val_loss: 0.4296 - val_accuracy: 0.8490
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4706 - accuracy: 0.8338 - val_loss: 0.4139 - val_accuracy: 0.8538
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4631 - accuracy: 0.8363 - val_loss: 0.4065 - val_accuracy: 0.8570
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4565 - accuracy: 0.8395 - val_loss: 0.4187 - val_accuracy: 0.8536
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4508 - accuracy: 0.8415 - val_loss: 0.3997 - val_accuracy: 0.8582
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4472 - accuracy: 0.8427 - val_loss: 0.3927 - val_accuracy: 0.8628
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4417 - accuracy: 0.8446 - val_loss: 0.3863 - val_accuracy: 0.8640
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4392 - accuracy: 0.8451 - val_loss: 0.3985 - val_accuracy: 0.8590
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4360 - accuracy: 0.8468 - val_loss: 0.3831 - val_accuracy: 0.8646
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4323 - accuracy: 0.8483 - val_loss: 0.3782 - val_accuracy: 0.8678
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4300 - accuracy: 0.8483 - val_loss: 0.3756 - val_accuracy: 0.8688
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4281 - accuracy: 0.8486 - val_loss: 0.3783 - val_accuracy: 0.8660
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4272 - accuracy: 0.8492 - val_loss: 0.3741 - val_accuracy: 0.8673
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4262 - accuracy: 0.8501 - val_loss: 0.3787 - val_accuracy: 0.8643
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4250 - accuracy: 0.8503 - val_loss: 0.3743 - val_accuracy: 0.8700
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4256 - accuracy: 0.8495 - val_loss: 0.3728 - val_accuracy: 0.8682
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8194 - accuracy: 0.6129 - val_loss: 0.7487 - val_accuracy: 0.6555
# Epoch 2/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.6471 - accuracy: 0.7532 - val_loss: 0.5306 - val_accuracy: 0.8201
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5777 - accuracy: 0.7957 - val_loss: 0.5123 - val_accuracy: 0.8134
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5493 - accuracy: 0.8093 - val_loss: 0.4532 - val_accuracy: 0.8428
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5358 - accuracy: 0.8162 - val_loss: 0.4438 - val_accuracy: 0.8464
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5235 - accuracy: 0.8213 - val_loss: 0.4441 - val_accuracy: 0.8405
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5140 - accuracy: 0.8254 - val_loss: 0.4348 - val_accuracy: 0.8496
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5063 - accuracy: 0.8281 - val_loss: 0.4446 - val_accuracy: 0.8434
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5014 - accuracy: 0.8306 - val_loss: 0.4155 - val_accuracy: 0.8555
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4947 - accuracy: 0.8335 - val_loss: 0.4137 - val_accuracy: 0.8573
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4904 - accuracy: 0.8353 - val_loss: 0.4016 - val_accuracy: 0.8581
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4852 - accuracy: 0.8365 - val_loss: 0.4118 - val_accuracy: 0.8539
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4845 - accuracy: 0.8362 - val_loss: 0.4059 - val_accuracy: 0.8558
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4795 - accuracy: 0.8379 - val_loss: 0.4227 - val_accuracy: 0.8482
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4792 - accuracy: 0.8387 - val_loss: 0.3895 - val_accuracy: 0.8603
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4775 - accuracy: 0.8390 - val_loss: 0.3991 - val_accuracy: 0.8592
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4728 - accuracy: 0.8398 - val_loss: 0.3906 - val_accuracy: 0.8645
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4713 - accuracy: 0.8403 - val_loss: 0.3998 - val_accuracy: 0.8553
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4702 - accuracy: 0.8414 - val_loss: 0.4071 - val_accuracy: 0.8555
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4699 - accuracy: 0.8407 - val_loss: 0.3926 - val_accuracy: 0.8622
# Epoch 1/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.8049 - accuracy: 0.6383 - val_loss: 0.6238 - val_accuracy: 0.7969
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5884 - accuracy: 0.7847 - val_loss: 0.4850 - val_accuracy: 0.8367
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5292 - accuracy: 0.8087 - val_loss: 0.4509 - val_accuracy: 0.8418
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5043 - accuracy: 0.8187 - val_loss: 0.4347 - val_accuracy: 0.8479
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4889 - accuracy: 0.8239 - val_loss: 0.4284 - val_accuracy: 0.8496
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4796 - accuracy: 0.8281 - val_loss: 0.4210 - val_accuracy: 0.8512
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4723 - accuracy: 0.8317 - val_loss: 0.4197 - val_accuracy: 0.8505
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4651 - accuracy: 0.8350 - val_loss: 0.4112 - val_accuracy: 0.8564
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4582 - accuracy: 0.8374 - val_loss: 0.4020 - val_accuracy: 0.8605
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4533 - accuracy: 0.8398 - val_loss: 0.4023 - val_accuracy: 0.8579
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4490 - accuracy: 0.8411 - val_loss: 0.3972 - val_accuracy: 0.8594
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4455 - accuracy: 0.8426 - val_loss: 0.3959 - val_accuracy: 0.8599
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4424 - accuracy: 0.8445 - val_loss: 0.3937 - val_accuracy: 0.8617
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4392 - accuracy: 0.8445 - val_loss: 0.3856 - val_accuracy: 0.8638
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4384 - accuracy: 0.8449 - val_loss: 0.3814 - val_accuracy: 0.8652
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4343 - accuracy: 0.8465 - val_loss: 0.3801 - val_accuracy: 0.8655
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4328 - accuracy: 0.8470 - val_loss: 0.3818 - val_accuracy: 0.8653
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4314 - accuracy: 0.8482 - val_loss: 0.3803 - val_accuracy: 0.8640
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4293 - accuracy: 0.8490 - val_loss: 0.3754 - val_accuracy: 0.8681
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4278 - accuracy: 0.8490 - val_loss: 0.3767 - val_accuracy: 0.8677
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8103 - accuracy: 0.6231 - val_loss: 0.6645 - val_accuracy: 0.7604
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6225 - accuracy: 0.7708 - val_loss: 0.5075 - val_accuracy: 0.8208
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5595 - accuracy: 0.8054 - val_loss: 0.4633 - val_accuracy: 0.8440
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5350 - accuracy: 0.8161 - val_loss: 0.4679 - val_accuracy: 0.8353
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5194 - accuracy: 0.8239 - val_loss: 0.4453 - val_accuracy: 0.8438
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5112 - accuracy: 0.8281 - val_loss: 0.4359 - val_accuracy: 0.8518
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5034 - accuracy: 0.8314 - val_loss: 0.4303 - val_accuracy: 0.8541
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4961 - accuracy: 0.8342 - val_loss: 0.4485 - val_accuracy: 0.8478
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4914 - accuracy: 0.8376 - val_loss: 0.4148 - val_accuracy: 0.8577
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4876 - accuracy: 0.8379 - val_loss: 0.4210 - val_accuracy: 0.8583
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4846 - accuracy: 0.8390 - val_loss: 0.4295 - val_accuracy: 0.8550
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4804 - accuracy: 0.8409 - val_loss: 0.4037 - val_accuracy: 0.8613
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4768 - accuracy: 0.8428 - val_loss: 0.3993 - val_accuracy: 0.8652
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4763 - accuracy: 0.8417 - val_loss: 0.4085 - val_accuracy: 0.8591
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4750 - accuracy: 0.8414 - val_loss: 0.4099 - val_accuracy: 0.8584
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4717 - accuracy: 0.8438 - val_loss: 0.3998 - val_accuracy: 0.8643
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4693 - accuracy: 0.8439 - val_loss: 0.4036 - val_accuracy: 0.8604
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4683 - accuracy: 0.8453 - val_loss: 0.3904 - val_accuracy: 0.8644
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4678 - accuracy: 0.8437 - val_loss: 0.3956 - val_accuracy: 0.8630
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4666 - accuracy: 0.8452 - val_loss: 0.3882 - val_accuracy: 0.8654
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.7855 - accuracy: 0.6555 - val_loss: 0.5932 - val_accuracy: 0.8124
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5713 - accuracy: 0.7933 - val_loss: 0.4625 - val_accuracy: 0.8403
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5110 - accuracy: 0.8185 - val_loss: 0.4306 - val_accuracy: 0.8510
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4895 - accuracy: 0.8272 - val_loss: 0.4288 - val_accuracy: 0.8493
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4768 - accuracy: 0.8326 - val_loss: 0.4217 - val_accuracy: 0.8515
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4704 - accuracy: 0.8349 - val_loss: 0.4055 - val_accuracy: 0.8604
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4631 - accuracy: 0.8384 - val_loss: 0.4075 - val_accuracy: 0.8597
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4595 - accuracy: 0.8397 - val_loss: 0.4011 - val_accuracy: 0.8617
# Epoch 9/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4539 - accuracy: 0.8412 - val_loss: 0.4027 - val_accuracy: 0.8599
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4506 - accuracy: 0.8423 - val_loss: 0.3997 - val_accuracy: 0.8598
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4478 - accuracy: 0.8431 - val_loss: 0.3951 - val_accuracy: 0.8626
# Epoch 12/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4448 - accuracy: 0.8445 - val_loss: 0.3904 - val_accuracy: 0.8624
# Epoch 13/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4416 - accuracy: 0.8448 - val_loss: 0.3849 - val_accuracy: 0.8640
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4409 - accuracy: 0.8447 - val_loss: 0.3855 - val_accuracy: 0.8646
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4384 - accuracy: 0.8458 - val_loss: 0.3874 - val_accuracy: 0.8625
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4377 - accuracy: 0.8459 - val_loss: 0.3837 - val_accuracy: 0.8649
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4347 - accuracy: 0.8467 - val_loss: 0.3769 - val_accuracy: 0.8658
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4326 - accuracy: 0.8474 - val_loss: 0.3779 - val_accuracy: 0.8663
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4317 - accuracy: 0.8470 - val_loss: 0.3840 - val_accuracy: 0.8625
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4311 - accuracy: 0.8490 - val_loss: 0.3758 - val_accuracy: 0.8677
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8146 - accuracy: 0.6219 - val_loss: 0.6788 - val_accuracy: 0.6867
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.6269 - accuracy: 0.7681 - val_loss: 0.5135 - val_accuracy: 0.8206
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5615 - accuracy: 0.8016 - val_loss: 0.4725 - val_accuracy: 0.8310
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5373 - accuracy: 0.8118 - val_loss: 0.4736 - val_accuracy: 0.8273
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5229 - accuracy: 0.8196 - val_loss: 0.4576 - val_accuracy: 0.8320
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5121 - accuracy: 0.8244 - val_loss: 0.4505 - val_accuracy: 0.8382
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5050 - accuracy: 0.8277 - val_loss: 0.4106 - val_accuracy: 0.8577
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4993 - accuracy: 0.8308 - val_loss: 0.4233 - val_accuracy: 0.8597
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4945 - accuracy: 0.8333 - val_loss: 0.4202 - val_accuracy: 0.8528
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4866 - accuracy: 0.8361 - val_loss: 0.4242 - val_accuracy: 0.8531
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4853 - accuracy: 0.8360 - val_loss: 0.4216 - val_accuracy: 0.8532
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4821 - accuracy: 0.8376 - val_loss: 0.4173 - val_accuracy: 0.8533
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4794 - accuracy: 0.8391 - val_loss: 0.4052 - val_accuracy: 0.8597
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4758 - accuracy: 0.8402 - val_loss: 0.4022 - val_accuracy: 0.8599
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4742 - accuracy: 0.8413 - val_loss: 0.4021 - val_accuracy: 0.8659
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4725 - accuracy: 0.8417 - val_loss: 0.3944 - val_accuracy: 0.8615
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4710 - accuracy: 0.8419 - val_loss: 0.3966 - val_accuracy: 0.8633
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4692 - accuracy: 0.8433 - val_loss: 0.4170 - val_accuracy: 0.8512
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4666 - accuracy: 0.8438 - val_loss: 0.3842 - val_accuracy: 0.8660
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4657 - accuracy: 0.8445 - val_loss: 0.3892 - val_accuracy: 0.8651
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8004 - accuracy: 0.6347 - val_loss: 0.6217 - val_accuracy: 0.8111
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5852 - accuracy: 0.7842 - val_loss: 0.4814 - val_accuracy: 0.8380
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5250 - accuracy: 0.8110 - val_loss: 0.4512 - val_accuracy: 0.8455
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5019 - accuracy: 0.8211 - val_loss: 0.4339 - val_accuracy: 0.8510
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4895 - accuracy: 0.8273 - val_loss: 0.4313 - val_accuracy: 0.8522
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4785 - accuracy: 0.8315 - val_loss: 0.4192 - val_accuracy: 0.8553
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4699 - accuracy: 0.8338 - val_loss: 0.4113 - val_accuracy: 0.8579
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4621 - accuracy: 0.8382 - val_loss: 0.4087 - val_accuracy: 0.8578
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4569 - accuracy: 0.8399 - val_loss: 0.4052 - val_accuracy: 0.8587
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4519 - accuracy: 0.8413 - val_loss: 0.4026 - val_accuracy: 0.8576
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4469 - accuracy: 0.8432 - val_loss: 0.4063 - val_accuracy: 0.8563
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4434 - accuracy: 0.8445 - val_loss: 0.3938 - val_accuracy: 0.8593
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4422 - accuracy: 0.8448 - val_loss: 0.3922 - val_accuracy: 0.8604
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4403 - accuracy: 0.8458 - val_loss: 0.3868 - val_accuracy: 0.8633
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4387 - accuracy: 0.8470 - val_loss: 0.3859 - val_accuracy: 0.8631
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4347 - accuracy: 0.8476 - val_loss: 0.3896 - val_accuracy: 0.8615
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4331 - accuracy: 0.8482 - val_loss: 0.3874 - val_accuracy: 0.8646
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4317 - accuracy: 0.8485 - val_loss: 0.3821 - val_accuracy: 0.8666
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4302 - accuracy: 0.8491 - val_loss: 0.3873 - val_accuracy: 0.8623
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4288 - accuracy: 0.8498 - val_loss: 0.3812 - val_accuracy: 0.8653
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8027 - accuracy: 0.6352 - val_loss: 0.6387 - val_accuracy: 0.7787
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6106 - accuracy: 0.7822 - val_loss: 0.5361 - val_accuracy: 0.8044
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5491 - accuracy: 0.8110 - val_loss: 0.4995 - val_accuracy: 0.8214
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5286 - accuracy: 0.8193 - val_loss: 0.4405 - val_accuracy: 0.8477
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5137 - accuracy: 0.8254 - val_loss: 0.4474 - val_accuracy: 0.8417
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5052 - accuracy: 0.8292 - val_loss: 0.4343 - val_accuracy: 0.8488
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4981 - accuracy: 0.8328 - val_loss: 0.4491 - val_accuracy: 0.8413
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4908 - accuracy: 0.8361 - val_loss: 0.4267 - val_accuracy: 0.8498
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4861 - accuracy: 0.8388 - val_loss: 0.4095 - val_accuracy: 0.8604
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4810 - accuracy: 0.8401 - val_loss: 0.4093 - val_accuracy: 0.8581
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4785 - accuracy: 0.8413 - val_loss: 0.4154 - val_accuracy: 0.8540
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4739 - accuracy: 0.8420 - val_loss: 0.4280 - val_accuracy: 0.8486
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4706 - accuracy: 0.8428 - val_loss: 0.4174 - val_accuracy: 0.8517
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4693 - accuracy: 0.8436 - val_loss: 0.4101 - val_accuracy: 0.8587
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4664 - accuracy: 0.8444 - val_loss: 0.4047 - val_accuracy: 0.8563
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4645 - accuracy: 0.8458 - val_loss: 0.4080 - val_accuracy: 0.8588
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4629 - accuracy: 0.8470 - val_loss: 0.4191 - val_accuracy: 0.8521
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4613 - accuracy: 0.8465 - val_loss: 0.4140 - val_accuracy: 0.8548
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4610 - accuracy: 0.8461 - val_loss: 0.3933 - val_accuracy: 0.8631
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4604 - accuracy: 0.8475 - val_loss: 0.4023 - val_accuracy: 0.8586
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8083 - accuracy: 0.6425 - val_loss: 0.6161 - val_accuracy: 0.8020
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5993 - accuracy: 0.7780 - val_loss: 0.4945 - val_accuracy: 0.8327
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5385 - accuracy: 0.8037 - val_loss: 0.4535 - val_accuracy: 0.8419
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5122 - accuracy: 0.8152 - val_loss: 0.4338 - val_accuracy: 0.8538
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4972 - accuracy: 0.8218 - val_loss: 0.4297 - val_accuracy: 0.8519
# Epoch 6/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4887 - accuracy: 0.8249 - val_loss: 0.4294 - val_accuracy: 0.8497
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4774 - accuracy: 0.8292 - val_loss: 0.4134 - val_accuracy: 0.8571
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4737 - accuracy: 0.8307 - val_loss: 0.4092 - val_accuracy: 0.8602
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4642 - accuracy: 0.8340 - val_loss: 0.4014 - val_accuracy: 0.8593
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4620 - accuracy: 0.8349 - val_loss: 0.4034 - val_accuracy: 0.8607
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4576 - accuracy: 0.8376 - val_loss: 0.3949 - val_accuracy: 0.8632
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4540 - accuracy: 0.8380 - val_loss: 0.3911 - val_accuracy: 0.8623
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4525 - accuracy: 0.8392 - val_loss: 0.3929 - val_accuracy: 0.8620
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4488 - accuracy: 0.8406 - val_loss: 0.3966 - val_accuracy: 0.8609
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4472 - accuracy: 0.8404 - val_loss: 0.3909 - val_accuracy: 0.8622
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4446 - accuracy: 0.8419 - val_loss: 0.3965 - val_accuracy: 0.8608
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4429 - accuracy: 0.8416 - val_loss: 0.3874 - val_accuracy: 0.8648
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4397 - accuracy: 0.8441 - val_loss: 0.3816 - val_accuracy: 0.8657
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4403 - accuracy: 0.8427 - val_loss: 0.3781 - val_accuracy: 0.8670
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4382 - accuracy: 0.8450 - val_loss: 0.3781 - val_accuracy: 0.8665
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8653 - accuracy: 0.5829 - val_loss: 0.7470 - val_accuracy: 0.6527
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6717 - accuracy: 0.7359 - val_loss: 0.5483 - val_accuracy: 0.8085
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5919 - accuracy: 0.7917 - val_loss: 0.5134 - val_accuracy: 0.8187
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5633 - accuracy: 0.8049 - val_loss: 0.4785 - val_accuracy: 0.8326
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5458 - accuracy: 0.8125 - val_loss: 0.4467 - val_accuracy: 0.8454
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5309 - accuracy: 0.8206 - val_loss: 0.4405 - val_accuracy: 0.8467
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5213 - accuracy: 0.8247 - val_loss: 0.4459 - val_accuracy: 0.8458
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5139 - accuracy: 0.8275 - val_loss: 0.4297 - val_accuracy: 0.8498
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5049 - accuracy: 0.8303 - val_loss: 0.4254 - val_accuracy: 0.8525
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5011 - accuracy: 0.8316 - val_loss: 0.4082 - val_accuracy: 0.8609
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4966 - accuracy: 0.8340 - val_loss: 0.3987 - val_accuracy: 0.8633
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4932 - accuracy: 0.8342 - val_loss: 0.4010 - val_accuracy: 0.8601
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4892 - accuracy: 0.8367 - val_loss: 0.3981 - val_accuracy: 0.8621
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4878 - accuracy: 0.8371 - val_loss: 0.3959 - val_accuracy: 0.8601
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4855 - accuracy: 0.8385 - val_loss: 0.4046 - val_accuracy: 0.8615
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4834 - accuracy: 0.8387 - val_loss: 0.3929 - val_accuracy: 0.8628
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4793 - accuracy: 0.8396 - val_loss: 0.4012 - val_accuracy: 0.8609
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4820 - accuracy: 0.8396 - val_loss: 0.4045 - val_accuracy: 0.8596
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4768 - accuracy: 0.8414 - val_loss: 0.3921 - val_accuracy: 0.8675
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4757 - accuracy: 0.8414 - val_loss: 0.3864 - val_accuracy: 0.8672
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8095 - accuracy: 0.6332 - val_loss: 0.6446 - val_accuracy: 0.7249
# Epoch 2/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.6036 - accuracy: 0.7763 - val_loss: 0.4849 - val_accuracy: 0.8389
# Epoch 3/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5334 - accuracy: 0.8096 - val_loss: 0.4451 - val_accuracy: 0.8470
# Epoch 4/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.5069 - accuracy: 0.8225 - val_loss: 0.4345 - val_accuracy: 0.8541
# Epoch 5/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4893 - accuracy: 0.8287 - val_loss: 0.4125 - val_accuracy: 0.8561
# Epoch 6/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4768 - accuracy: 0.8333 - val_loss: 0.4051 - val_accuracy: 0.8587
# Epoch 7/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4684 - accuracy: 0.8375 - val_loss: 0.3984 - val_accuracy: 0.8635
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4620 - accuracy: 0.8394 - val_loss: 0.3912 - val_accuracy: 0.8641
# Epoch 9/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4546 - accuracy: 0.8416 - val_loss: 0.4029 - val_accuracy: 0.8581
# Epoch 10/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4482 - accuracy: 0.8438 - val_loss: 0.3845 - val_accuracy: 0.8657
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4425 - accuracy: 0.8462 - val_loss: 0.3904 - val_accuracy: 0.8637
# Epoch 12/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4393 - accuracy: 0.8466 - val_loss: 0.3726 - val_accuracy: 0.8708
# Epoch 13/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4344 - accuracy: 0.8484 - val_loss: 0.3795 - val_accuracy: 0.8687
# Epoch 14/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4336 - accuracy: 0.8484 - val_loss: 0.3728 - val_accuracy: 0.8696
# Epoch 15/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4312 - accuracy: 0.8496 - val_loss: 0.3686 - val_accuracy: 0.8693
# Epoch 16/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4288 - accuracy: 0.8506 - val_loss: 0.3788 - val_accuracy: 0.8670
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4276 - accuracy: 0.8515 - val_loss: 0.3698 - val_accuracy: 0.8708
# Epoch 18/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4243 - accuracy: 0.8513 - val_loss: 0.3630 - val_accuracy: 0.8731
# Epoch 19/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4235 - accuracy: 0.8517 - val_loss: 0.3635 - val_accuracy: 0.8731
# Epoch 20/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4216 - accuracy: 0.8528 - val_loss: 0.3650 - val_accuracy: 0.8720
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8486 - accuracy: 0.5788 - val_loss: 0.7945 - val_accuracy: 0.6230
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6876 - accuracy: 0.7049 - val_loss: 0.5890 - val_accuracy: 0.7902
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6136 - accuracy: 0.7642 - val_loss: 0.5287 - val_accuracy: 0.8126
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5820 - accuracy: 0.7822 - val_loss: 0.5072 - val_accuracy: 0.8127
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5604 - accuracy: 0.7972 - val_loss: 0.4631 - val_accuracy: 0.8387
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5467 - accuracy: 0.8056 - val_loss: 0.4872 - val_accuracy: 0.8284
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5352 - accuracy: 0.8129 - val_loss: 0.4849 - val_accuracy: 0.8308
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5243 - accuracy: 0.8187 - val_loss: 0.4347 - val_accuracy: 0.8486
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5148 - accuracy: 0.8226 - val_loss: 0.4212 - val_accuracy: 0.8579
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5086 - accuracy: 0.8261 - val_loss: 0.4166 - val_accuracy: 0.8569
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5031 - accuracy: 0.8289 - val_loss: 0.4194 - val_accuracy: 0.8610
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4999 - accuracy: 0.8301 - val_loss: 0.3927 - val_accuracy: 0.8659
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4957 - accuracy: 0.8328 - val_loss: 0.4476 - val_accuracy: 0.8504
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4925 - accuracy: 0.8333 - val_loss: 0.4262 - val_accuracy: 0.8569
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4893 - accuracy: 0.8340 - val_loss: 0.4033 - val_accuracy: 0.8646
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4881 - accuracy: 0.8358 - val_loss: 0.4220 - val_accuracy: 0.8569
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4854 - accuracy: 0.8355 - val_loss: 0.4106 - val_accuracy: 0.8625
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4816 - accuracy: 0.8363 - val_loss: 0.3937 - val_accuracy: 0.8642
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4809 - accuracy: 0.8370 - val_loss: 0.3968 - val_accuracy: 0.8670
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4784 - accuracy: 0.8384 - val_loss: 0.4019 - val_accuracy: 0.8647
# Epoch 1/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.8215 - accuracy: 0.6167 - val_loss: 0.6655 - val_accuracy: 0.7450
# Epoch 2/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.6103 - accuracy: 0.7692 - val_loss: 0.5023 - val_accuracy: 0.8213
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5310 - accuracy: 0.8081 - val_loss: 0.4445 - val_accuracy: 0.8474
# Epoch 4/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.5031 - accuracy: 0.8199 - val_loss: 0.4352 - val_accuracy: 0.8528
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4830 - accuracy: 0.8285 - val_loss: 0.4198 - val_accuracy: 0.8557
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4714 - accuracy: 0.8339 - val_loss: 0.4113 - val_accuracy: 0.8571
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4631 - accuracy: 0.8370 - val_loss: 0.4086 - val_accuracy: 0.8597
# Epoch 8/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4549 - accuracy: 0.8403 - val_loss: 0.4090 - val_accuracy: 0.8588
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4496 - accuracy: 0.8408 - val_loss: 0.3996 - val_accuracy: 0.8595
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4430 - accuracy: 0.8441 - val_loss: 0.3901 - val_accuracy: 0.8640
# Epoch 11/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4398 - accuracy: 0.8442 - val_loss: 0.3915 - val_accuracy: 0.8612
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4355 - accuracy: 0.8462 - val_loss: 0.3829 - val_accuracy: 0.8640
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4339 - accuracy: 0.8466 - val_loss: 0.3935 - val_accuracy: 0.8600
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4315 - accuracy: 0.8476 - val_loss: 0.3873 - val_accuracy: 0.8614
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4269 - accuracy: 0.8495 - val_loss: 0.3823 - val_accuracy: 0.8635
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4274 - accuracy: 0.8480 - val_loss: 0.3726 - val_accuracy: 0.8685
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4246 - accuracy: 0.8496 - val_loss: 0.3746 - val_accuracy: 0.8675
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4229 - accuracy: 0.8500 - val_loss: 0.3758 - val_accuracy: 0.8669
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4225 - accuracy: 0.8515 - val_loss: 0.3699 - val_accuracy: 0.8692
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4223 - accuracy: 0.8503 - val_loss: 0.3711 - val_accuracy: 0.8682
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8302 - accuracy: 0.5954 - val_loss: 0.7002 - val_accuracy: 0.6795
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6454 - accuracy: 0.7470 - val_loss: 0.5375 - val_accuracy: 0.8158
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5753 - accuracy: 0.7929 - val_loss: 0.4796 - val_accuracy: 0.8339
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5411 - accuracy: 0.8103 - val_loss: 0.4645 - val_accuracy: 0.8350
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5254 - accuracy: 0.8184 - val_loss: 0.4986 - val_accuracy: 0.8204
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5154 - accuracy: 0.8242 - val_loss: 0.4460 - val_accuracy: 0.8437
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5070 - accuracy: 0.8277 - val_loss: 0.4511 - val_accuracy: 0.8397
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5008 - accuracy: 0.8313 - val_loss: 0.4141 - val_accuracy: 0.8602
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4948 - accuracy: 0.8324 - val_loss: 0.4371 - val_accuracy: 0.8464
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4919 - accuracy: 0.8346 - val_loss: 0.4091 - val_accuracy: 0.8610
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4863 - accuracy: 0.8366 - val_loss: 0.4306 - val_accuracy: 0.8528
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4828 - accuracy: 0.8370 - val_loss: 0.4121 - val_accuracy: 0.8550
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4819 - accuracy: 0.8383 - val_loss: 0.3998 - val_accuracy: 0.8620
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4798 - accuracy: 0.8395 - val_loss: 0.4153 - val_accuracy: 0.8559
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4754 - accuracy: 0.8417 - val_loss: 0.3964 - val_accuracy: 0.8609
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4741 - accuracy: 0.8413 - val_loss: 0.4013 - val_accuracy: 0.8608
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4719 - accuracy: 0.8420 - val_loss: 0.3938 - val_accuracy: 0.8593
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4696 - accuracy: 0.8426 - val_loss: 0.4222 - val_accuracy: 0.8495
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4689 - accuracy: 0.8435 - val_loss: 0.3954 - val_accuracy: 0.8651
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4673 - accuracy: 0.8439 - val_loss: 0.4068 - val_accuracy: 0.8537
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.7842 - accuracy: 0.6533 - val_loss: 0.6061 - val_accuracy: 0.8117
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5787 - accuracy: 0.7868 - val_loss: 0.4825 - val_accuracy: 0.8327
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5150 - accuracy: 0.8155 - val_loss: 0.4505 - val_accuracy: 0.8401
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4897 - accuracy: 0.8267 - val_loss: 0.4485 - val_accuracy: 0.8460
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4753 - accuracy: 0.8330 - val_loss: 0.4114 - val_accuracy: 0.8577
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4649 - accuracy: 0.8367 - val_loss: 0.4193 - val_accuracy: 0.8561
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4567 - accuracy: 0.8408 - val_loss: 0.4014 - val_accuracy: 0.8605
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4517 - accuracy: 0.8431 - val_loss: 0.3988 - val_accuracy: 0.8623
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4460 - accuracy: 0.8448 - val_loss: 0.3959 - val_accuracy: 0.8621
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4401 - accuracy: 0.8472 - val_loss: 0.3924 - val_accuracy: 0.8646
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4373 - accuracy: 0.8476 - val_loss: 0.3888 - val_accuracy: 0.8643
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4344 - accuracy: 0.8484 - val_loss: 0.4005 - val_accuracy: 0.8576
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4328 - accuracy: 0.8487 - val_loss: 0.3904 - val_accuracy: 0.8646
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4278 - accuracy: 0.8505 - val_loss: 0.3807 - val_accuracy: 0.8667
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4271 - accuracy: 0.8501 - val_loss: 0.3767 - val_accuracy: 0.8663
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4256 - accuracy: 0.8504 - val_loss: 0.3803 - val_accuracy: 0.8670
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4235 - accuracy: 0.8519 - val_loss: 0.3732 - val_accuracy: 0.8682
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4221 - accuracy: 0.8518 - val_loss: 0.3773 - val_accuracy: 0.8664
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4207 - accuracy: 0.8525 - val_loss: 0.3741 - val_accuracy: 0.8667
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4208 - accuracy: 0.8519 - val_loss: 0.3736 - val_accuracy: 0.8666
# Epoch 1/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.8028 - accuracy: 0.6270 - val_loss: 0.6740 - val_accuracy: 0.7428
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6153 - accuracy: 0.7784 - val_loss: 0.4942 - val_accuracy: 0.8288
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5592 - accuracy: 0.8036 - val_loss: 0.4599 - val_accuracy: 0.8335
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5375 - accuracy: 0.8124 - val_loss: 0.4535 - val_accuracy: 0.8347
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5293 - accuracy: 0.8161 - val_loss: 0.4495 - val_accuracy: 0.8371
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5226 - accuracy: 0.8210 - val_loss: 0.4435 - val_accuracy: 0.8416
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5140 - accuracy: 0.8234 - val_loss: 0.4584 - val_accuracy: 0.8308
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5057 - accuracy: 0.8281 - val_loss: 0.4346 - val_accuracy: 0.8477
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5028 - accuracy: 0.8301 - val_loss: 0.4267 - val_accuracy: 0.8495
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4995 - accuracy: 0.8323 - val_loss: 0.4275 - val_accuracy: 0.8511
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4940 - accuracy: 0.8352 - val_loss: 0.4445 - val_accuracy: 0.8412
# Epoch 12/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4933 - accuracy: 0.8353 - val_loss: 0.4386 - val_accuracy: 0.8495
# Epoch 13/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4901 - accuracy: 0.8371 - val_loss: 0.4149 - val_accuracy: 0.8577
# Epoch 14/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4867 - accuracy: 0.8382 - val_loss: 0.4179 - val_accuracy: 0.8589
# Epoch 15/20
# 1155/1155 [==============================] - 5s 4ms/step - loss: 0.4852 - accuracy: 0.8392 - val_loss: 0.4051 - val_accuracy: 0.8622
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4837 - accuracy: 0.8403 - val_loss: 0.4168 - val_accuracy: 0.8568
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4813 - accuracy: 0.8407 - val_loss: 0.3932 - val_accuracy: 0.8651
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4806 - accuracy: 0.8418 - val_loss: 0.4036 - val_accuracy: 0.8634
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4777 - accuracy: 0.8417 - val_loss: 0.4087 - val_accuracy: 0.8633
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4761 - accuracy: 0.8432 - val_loss: 0.3897 - val_accuracy: 0.8666
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8227 - accuracy: 0.6255 - val_loss: 0.6509 - val_accuracy: 0.7536
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6207 - accuracy: 0.7667 - val_loss: 0.5136 - val_accuracy: 0.8393
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5417 - accuracy: 0.8049 - val_loss: 0.4491 - val_accuracy: 0.8470
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5108 - accuracy: 0.8185 - val_loss: 0.4434 - val_accuracy: 0.8456
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4959 - accuracy: 0.8241 - val_loss: 0.4352 - val_accuracy: 0.8475
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4871 - accuracy: 0.8280 - val_loss: 0.4241 - val_accuracy: 0.8540
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4792 - accuracy: 0.8300 - val_loss: 0.4150 - val_accuracy: 0.8548
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4746 - accuracy: 0.8323 - val_loss: 0.4121 - val_accuracy: 0.8570
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4706 - accuracy: 0.8331 - val_loss: 0.4133 - val_accuracy: 0.8565
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4673 - accuracy: 0.8348 - val_loss: 0.4056 - val_accuracy: 0.8582
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4623 - accuracy: 0.8364 - val_loss: 0.4026 - val_accuracy: 0.8590
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4605 - accuracy: 0.8367 - val_loss: 0.4054 - val_accuracy: 0.8562
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4589 - accuracy: 0.8379 - val_loss: 0.3973 - val_accuracy: 0.8590
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4562 - accuracy: 0.8383 - val_loss: 0.3935 - val_accuracy: 0.8617
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4536 - accuracy: 0.8405 - val_loss: 0.3955 - val_accuracy: 0.8590
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4519 - accuracy: 0.8407 - val_loss: 0.3935 - val_accuracy: 0.8609
# Epoch 17/20
# 1155/1155 [==============================] - 4s 3ms/step - loss: 0.4487 - accuracy: 0.8413 - val_loss: 0.3954 - val_accuracy: 0.8601
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4475 - accuracy: 0.8424 - val_loss: 0.3880 - val_accuracy: 0.8636
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4447 - accuracy: 0.8431 - val_loss: 0.3922 - val_accuracy: 0.8603
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4427 - accuracy: 0.8449 - val_loss: 0.3903 - val_accuracy: 0.8620
# Epoch 1/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.8098 - accuracy: 0.6111 - val_loss: 0.6549 - val_accuracy: 0.7242
# Epoch 2/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.6295 - accuracy: 0.7611 - val_loss: 0.5056 - val_accuracy: 0.8248
# Epoch 3/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5670 - accuracy: 0.7991 - val_loss: 0.4784 - val_accuracy: 0.8244
# Epoch 4/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5391 - accuracy: 0.8126 - val_loss: 0.4646 - val_accuracy: 0.8335
# Epoch 5/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5228 - accuracy: 0.8204 - val_loss: 0.4536 - val_accuracy: 0.8309
# Epoch 6/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5102 - accuracy: 0.8270 - val_loss: 0.4622 - val_accuracy: 0.8278
# Epoch 7/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5050 - accuracy: 0.8287 - val_loss: 0.4408 - val_accuracy: 0.8372
# Epoch 8/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.5000 - accuracy: 0.8331 - val_loss: 0.4452 - val_accuracy: 0.8361
# Epoch 9/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4922 - accuracy: 0.8350 - val_loss: 0.4092 - val_accuracy: 0.8611
# Epoch 10/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4870 - accuracy: 0.8367 - val_loss: 0.4158 - val_accuracy: 0.8495
# Epoch 11/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4852 - accuracy: 0.8378 - val_loss: 0.4284 - val_accuracy: 0.8403
# Epoch 12/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4823 - accuracy: 0.8386 - val_loss: 0.3969 - val_accuracy: 0.8616
# Epoch 13/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4759 - accuracy: 0.8409 - val_loss: 0.4080 - val_accuracy: 0.8597
# Epoch 14/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4760 - accuracy: 0.8406 - val_loss: 0.3933 - val_accuracy: 0.8654
# Epoch 15/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4724 - accuracy: 0.8418 - val_loss: 0.3940 - val_accuracy: 0.8652
# Epoch 16/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4721 - accuracy: 0.8411 - val_loss: 0.3902 - val_accuracy: 0.8649
# Epoch 17/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4687 - accuracy: 0.8425 - val_loss: 0.4346 - val_accuracy: 0.8401
# Epoch 18/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4681 - accuracy: 0.8428 - val_loss: 0.3876 - val_accuracy: 0.8681
# Epoch 19/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4657 - accuracy: 0.8432 - val_loss: 0.3961 - val_accuracy: 0.8649
# Epoch 20/20
# 1155/1155 [==============================] - 4s 4ms/step - loss: 0.4641 - accuracy: 0.8450 - val_loss: 0.3983 - val_accuracy: 0.8653

# %%
epochs = np.linspace(0,19,20)

train_acc_mean2 = np.average(np.vstack(train_acc2), axis = 0)
train_loss_mean2 = np.average(np.vstack(train_loss2), axis = 0)
train_acc_std2 = np.std(np.vstack(train_acc2), axis = 0)
train_loss_std2 = np.std(np.vstack(train_loss2), axis = 0)

val_acc_mean2 = np.average(np.vstack(val_acc2), axis = 0)
val_loss_mean2 = np.average(np.vstack(val_loss2), axis = 0)
val_acc_std2 = np.std(np.vstack(val_acc2), axis = 0)
val_loss_std2 = np.std(np.vstack(val_loss2), axis = 0)

#--------------------------------------------------------------#

train_acc_mean2w = np.average(np.vstack(train_accw), axis = 0)
train_loss_mean2w = np.average(np.vstack(train_lossw), axis = 0)
train_acc_std2w = np.std(np.vstack(train_accw), axis = 0)
train_loss_std2w = np.std(np.vstack(train_lossw), axis = 0)

val_acc_mean2w = np.average(np.vstack(val_acc2w), axis = 0)
val_loss_mean2w = np.average(np.vstack(val_loss2w), axis = 0)
val_acc_std2w = np.std(np.vstack(val_acc2w), axis = 0)
val_loss_std2w = np.std(np.vstack(val_loss2w), axis = 0)

# %%
plt.plot(train_acc_mean2, label = r'Train Accuracy', color = 'C0')
plt.fill_between(epochs, train_acc_mean2 - train_acc_std2, train_acc_mean2 + train_acc_std2, color = 'C0', alpha = 0.6)
plt.plot(val_acc_mean2, label = r'Val Accuracy', color = 'C1')
plt.fill_between(epochs, val_acc_mean2 - val_acc_std2, val_acc_mean2 + val_acc_std2, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Accuracy')
plt.legend()

# %%
plt.plot(train_acc_mean2w, label = r'Weighted train Accuracy', color = 'C0')
plt.fill_between(epochs, train_acc_mean2w - train_acc_std2w, train_acc_mean2w + train_acc_std2w, color = 'C0', alpha = 0.6)
plt.plot(val_acc_mean2w, label = r'Weighted val Accuracy', color = 'C1')
plt.fill_between(epochs, val_acc_mean2w - val_acc_std2w, val_acc_mean2w + val_acc_std2w, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Accuracy')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(train_acc_mean2, label = r'Train Accuracy', color = 'C0')
ax1.fill_between(epochs, train_acc_mean2 - train_acc_std2, train_acc_mean2 + train_acc_std2, color = 'C0', alpha = 0.6)
ax1.plot(val_acc_mean2, label = r'Val Accuracy', color = 'C1')
ax1.fill_between(epochs, val_acc_mean2 - val_acc_std2, val_acc_mean2 + val_acc_std2, color = 'C1', alpha = 0.6)
ax1.set_xlabel(r'Épocas')
ax1.set_ylabel(r'Accuracy')
ax1.legend()

#plt.subplot(1,2,2)
ax2.plot(train_acc_mean2w, label = r'Weighted train Accuracy', color = 'C0')
ax2.fill_between(epochs, train_acc_mean2w - train_acc_std2w, train_acc_mean2w + train_acc_std2w, color = 'C0', alpha = 0.6)
ax2.plot(val_acc_mean2w, label = r'Weighted val Accuracy', color = 'C1')
ax2.fill_between(epochs, val_acc_mean2w - val_acc_std2w, val_acc_mean2w + val_acc_std2w, color = 'C1', alpha = 0.6)
ax2.set_xlabel(r'Épocas')
ax2.set_ylabel(r'Accuracy')
ax2.legend()

# %%
plt.plot(train_loss_mean2, label = r'Train Loss', color = 'C0')
plt.fill_between(epochs, train_loss_mean2 - train_loss_std2, train_loss_mean2 + train_loss_std2, color = 'C0', alpha = 0.6)
plt.plot(val_loss_mean2, label = r'Val Loss', color = 'C1')
plt.fill_between(epochs, val_loss_mean2 - val_loss_std2, val_loss_mean2 + val_loss_std2, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Loss')
plt.legend()

# %%
plt.plot(train_loss_mean2w, label = r'Train Loss', color = 'C0')
plt.fill_between(epochs, train_loss_mean2w - train_loss_std2w, train_loss_mean2w + train_loss_std2w, color = 'C0', alpha = 0.6)
plt.plot(val_loss_mean2w, label = r'Val Loss', color = 'C1')
plt.fill_between(epochs, val_loss_mean2w - val_loss_std2w, val_loss_mean2w + val_loss_std2w, color = 'C1', alpha = 0.6)
plt.xlabel(r'Épocas')
plt.ylabel(r'Loss')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(train_loss_mean2, label = r'Train Loss', color = 'C0')
ax1.fill_between(epochs, train_loss_mean2 - train_loss_std2, train_loss_mean2 + train_loss_std2, color = 'C0', alpha = 0.6)
ax1.plot(val_loss_mean2, label = r'Val Loss', color = 'C1')
ax1.fill_between(epochs, val_loss_mean2 - val_loss_std2, val_loss_mean2 + val_loss_std2, color = 'C1', alpha = 0.6)
ax1.set_xlabel(r'Épocas')
ax1.set_ylabel(r'Loss')
ax1.legend()

#--------------------------------------------------------------#

ax2.plot(train_loss_mean2w, label = r'Weighted train Loss', color = 'C0')
ax2.fill_between(epochs, train_loss_mean2w - train_loss_std2w, train_loss_mean2w + train_loss_std2w, color = 'C0', alpha = 0.6)
ax2.plot(val_loss_mean2w, label = r'Weighted val Loss', color = 'C1')
ax2.fill_between(epochs, val_loss_mean2w - val_loss_std2w, val_loss_mean2w + val_loss_std2w, color = 'C1', alpha = 0.6)
ax2.set_xlabel(r'Épocas')
ax2.set_ylabel(r'Loss')
ax2.legend()

# %%
test_pred2 = model.predict(x_test2)
test_pred2w = modelw.predict(x_test2w)

# %%
cmatrix2 = confusion_matrix(np.array(y_test2), np.argmax(test_pred2, axis = 1))
cmatrix2
# Out:
# array([[ 8835,   974,  1058],
#        [  281, 17701,   643],
#        [  543,  1909,  4987]])

# %%
cmatrix2w = confusion_matrix(np.array(y_test2w), np.argmax(test_pred2w, axis = 1))
cmatrix2w
# Out:
# array([[ 8962,   703,  1202],
#        [  630, 16472,  1523],
#        [  470,  1180,  5789]])

# %%
labels = ['STAR', 'GALAXY', 'QSO']

# %%
precisions2 = []
precisiong2 = []
precisionq2 = []

recalls2 = []
recallg2 = []
recallq2 = []

for i in range(10):
  precisions2.append(np.array(precision2)[i][0])
  precisiong2.append(np.array(precision2)[i][1])
  precisionq2.append(np.array(precision2)[i][2])
  recalls2.append(np.array(recall2)[i][0])
  recallg2.append(np.array(recall2)[i][1])
  recallq2.append(np.array(recall2)[i][2])

#----------------------------------------------------#

precisions2w = []
precisiong2w = []
precisionq2w = []

recalls2w = []
recallg2w = []
recallq2w = []

for i in range(10):
  precisions2w.append(np.array(precision2w)[i][0])
  precisiong2w.append(np.array(precision2w)[i][1])
  precisionq2w.append(np.array(precision2w)[i][2])
  recalls2w.append(np.array(recall2w)[i][0])
  recallg2w.append(np.array(recall2w)[i][1])
  recallq2w.append(np.array(recall2w)[i][2])

# %%
plt.plot(np.average(np.vstack(recalls2), axis = 0),np.average(np.vstack(precisions2), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls2), axis = 0), np.average(np.vstack(precisions2), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(recallg2), axis = 0),np.average(np.vstack(precisiong2), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg2), axis = 0), np.average(np.vstack(precisiong2), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(recallq2), axis = 0),np.average(np.vstack(precisionq2), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallq2), axis = 0), np.average(np.vstack(precisionq2), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(recalls2), axis = 0), np.std(np.vstack(precisions2), axis = 0) + np.average(np.vstack(precisions2), axis = 0), - np.std(np.vstack(precisions2), axis = 0) + np.average(np.vstack(precisions2), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallg2), axis = 0), np.std(np.vstack(precisiong2), axis = 0) + np.average(np.vstack(precisiong2), axis = 0), - np.std(np.vstack(precisiong2), axis = 0) + np.average(np.vstack(precisiong2), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallq2), axis = 0), np.std(np.vstack(precisionq2), axis = 0) + np.average(np.vstack(precisionq2), axis = 0), - np.std(np.vstack(precisionq2), axis = 0) + np.average(np.vstack(precisionq2), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
plt.plot(np.average(np.vstack(recalls2w), axis = 0),np.average(np.vstack(precisions2w), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls2w), axis = 0), np.average(np.vstack(precisions2w), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(recallg2w), axis = 0),np.average(np.vstack(precisiong2w), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg2w), axis = 0), np.average(np.vstack(precisiong2w), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(recallq2w), axis = 0),np.average(np.vstack(precisionq2w), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallq2w), axis = 0), np.average(np.vstack(precisionq2w), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(recalls2w), axis = 0), np.std(np.vstack(precisions2w), axis = 0) + np.average(np.vstack(precisions2w), axis = 0), - np.std(np.vstack(precisions2w), axis = 0) + np.average(np.vstack(precisions2w), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallg2w), axis = 0), np.std(np.vstack(precisiong2w), axis = 0) + np.average(np.vstack(precisiong2w), axis = 0), - np.std(np.vstack(precisiong2w), axis = 0) + np.average(np.vstack(precisiong2w), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(recallq2w), axis = 0), np.std(np.vstack(precisionq2w), axis = 0) + np.average(np.vstack(precisionq2w), axis = 0), - np.std(np.vstack(precisionq2w), axis = 0) + np.average(np.vstack(precisionq2w), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'Recall')
plt.ylabel(r'Precision')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(np.average(np.vstack(recalls2), axis = 0),np.average(np.vstack(precisions2), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls2), axis = 0), np.average(np.vstack(precisions2), axis = 0)), color = 'C0')
ax1.plot(np.average(np.vstack(recallg2), axis = 0),np.average(np.vstack(precisiong2), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg2), axis = 0), np.average(np.vstack(precisiong2), axis = 0)), color = 'C1')
ax1.plot(np.average(np.vstack(recallq2), axis = 0),np.average(np.vstack(precisionq2), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallq2), axis = 0), np.average(np.vstack(precisionq2), axis = 0)), color = 'C2')
ax1.fill_between(np.average(np.vstack(recalls2), axis = 0), np.std(np.vstack(precisions2), axis = 0) + np.average(np.vstack(precisions2), axis = 0), - np.std(np.vstack(precisions2), axis = 0) + np.average(np.vstack(precisions2), axis = 0), color = 'C0', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(recallg2), axis = 0), np.std(np.vstack(precisiong2), axis = 0) + np.average(np.vstack(precisiong2), axis = 0), - np.std(np.vstack(precisiong2), axis = 0) + np.average(np.vstack(precisiong2), axis = 0), color = 'C1', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(recallq2), axis = 0), np.std(np.vstack(precisionq2), axis = 0) + np.average(np.vstack(precisionq2), axis = 0), - np.std(np.vstack(precisionq2), axis = 0) + np.average(np.vstack(precisionq2), axis = 0), color = 'C2', alpha = 0.5)

ax1.set_xlabel(r'Recall')
ax1.set_ylabel(r'Precision')
ax1.set_title(r'Baseline')
ax1.legend()

ax2.plot(np.average(np.vstack(recalls2w), axis = 0),np.average(np.vstack(precisions2w), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(recalls2w), axis = 0), np.average(np.vstack(precisions2w), axis = 0)), color = 'C0')
ax2.plot(np.average(np.vstack(recallg2w), axis = 0),np.average(np.vstack(precisiong2w), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(recallg2w), axis = 0), np.average(np.vstack(precisiong2w), axis = 0)), color = 'C1')
ax2.plot(np.average(np.vstack(recallq2w), axis = 0),np.average(np.vstack(precisionq2w), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(recallq2w), axis = 0), np.average(np.vstack(precisionq2w), axis = 0)), color = 'C2')
ax2.fill_between(np.average(np.vstack(recalls2w), axis = 0), np.std(np.vstack(precisions2w), axis = 0) + np.average(np.vstack(precisions2w), axis = 0), - np.std(np.vstack(precisions2w), axis = 0) + np.average(np.vstack(precisions2w), axis = 0), color = 'C0', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(recallg2w), axis = 0), np.std(np.vstack(precisiong2w), axis = 0) + np.average(np.vstack(precisiong2w), axis = 0), - np.std(np.vstack(precisiong2w), axis = 0) + np.average(np.vstack(precisiong2w), axis = 0), color = 'C1', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(recallq2w), axis = 0), np.std(np.vstack(precisionq2w), axis = 0) + np.average(np.vstack(precisionq2w), axis = 0), - np.std(np.vstack(precisionq2w), axis = 0) + np.average(np.vstack(precisionq2w), axis = 0), color = 'C2', alpha = 0.5)

ax2.set_xlabel(r'Recall')
ax2.set_ylabel(r'Precision')
ax2.set_title(r'Weighted')
ax2.legend()

# %%
tprs2 = []
tprg2 = []
tprq2 = []

fprs2 = []
fprg2 = []
fprq2 = []

for i in range(10):
  tprs2.append(np.array(tpr2)[i][0])
  tprg2.append(np.array(tpr2)[i][1])
  tprq2.append(np.array(tpr2)[i][2])
  fprs2.append(np.array(fpr2)[i][0])
  fprg2.append(np.array(fpr2)[i][1])
  fprq2.append(np.array(fpr2)[i][2])

#-----------------------------------------------------------#

tprs2w = []
tprg2w = []
tprq2w = []

fprs2w = []
fprg2w = []
fprq2w = []

for i in range(10):
  tprs2w.append(np.array(tpr2w)[i][0])
  tprg2w.append(np.array(tpr2w)[i][1])
  tprq2w.append(np.array(tpr2w)[i][2])
  fprs2w.append(np.array(fpr2w)[i][0])
  fprg2w.append(np.array(fpr2w)[i][1])
  fprq2w.append(np.array(fpr2w)[i][2])

# %%
plt.plot(np.average(np.vstack(fprs2), axis = 0),np.average(np.vstack(tprs2), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs2), axis = 0), np.average(np.vstack(tprs2), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(fprg2), axis = 0),np.average(np.vstack(tprg2), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg2), axis = 0), np.average(np.vstack(tprg2), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(fprq2), axis = 0),np.average(np.vstack(tprq2), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq2), axis = 0), np.average(np.vstack(tprq2), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(fprs2), axis = 0), np.std(np.vstack(tprs2), axis = 0) + np.average(np.vstack(tprs2), axis = 0), - np.std(np.vstack(tprs2), axis = 0) + np.average(np.vstack(tprs2), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprg2), axis = 0), np.std(np.vstack(tprg2), axis = 0) + np.average(np.vstack(tprg2), axis = 0), - np.std(np.vstack(tprg2), axis = 0) + np.average(np.vstack(tprg2), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprq2), axis = 0), np.std(np.vstack(tprq2), axis = 0) + np.average(np.vstack(tprq2), axis = 0), - np.std(np.vstack(tprq2), axis = 0) + np.average(np.vstack(tprq2), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'TPR')
plt.ylabel(r'FPR')
plt.legend()

# %%
plt.plot(np.average(np.vstack(fprs2w), axis = 0),np.average(np.vstack(tprs2w), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs2w), axis = 0), np.average(np.vstack(tprs2w), axis = 0)), color = 'C0')
plt.plot(np.average(np.vstack(fprg2w), axis = 0),np.average(np.vstack(tprg2w), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg2w), axis = 0), np.average(np.vstack(tprg2w), axis = 0)), color = 'C1')
plt.plot(np.average(np.vstack(fprq2w), axis = 0),np.average(np.vstack(tprq2w), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq2w), axis = 0), np.average(np.vstack(tprq2w), axis = 0)), color = 'C2')
plt.fill_between(np.average(np.vstack(fprs2w), axis = 0), np.std(np.vstack(tprs2w), axis = 0) + np.average(np.vstack(tprs2w), axis = 0), - np.std(np.vstack(tprs2w), axis = 0) + np.average(np.vstack(tprs2w), axis = 0), color = 'C0', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprg2w), axis = 0), np.std(np.vstack(tprg2w), axis = 0) + np.average(np.vstack(tprg2w), axis = 0), - np.std(np.vstack(tprg2w), axis = 0) + np.average(np.vstack(tprg2w), axis = 0), color = 'C1', alpha = 0.5)
plt.fill_between(np.average(np.vstack(fprq2w), axis = 0), np.std(np.vstack(tprq2w), axis = 0) + np.average(np.vstack(tprq2w), axis = 0), - np.std(np.vstack(tprq2w), axis = 0) + np.average(np.vstack(tprq2w), axis = 0), color = 'C2', alpha = 0.5)

plt.xlabel(r'TPR')
plt.ylabel(r'FPR')
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

ax1.plot(np.average(np.vstack(fprs2), axis = 0),np.average(np.vstack(tprs2), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs2), axis = 0), np.average(np.vstack(tprs2), axis = 0)), color = 'C0')
ax1.plot(np.average(np.vstack(fprg2), axis = 0),np.average(np.vstack(tprg2), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg2), axis = 0), np.average(np.vstack(tprg2), axis = 0)), color = 'C1')
ax1.plot(np.average(np.vstack(fprq2), axis = 0),np.average(np.vstack(tprq2), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq2), axis = 0), np.average(np.vstack(tprq2), axis = 0)), color = 'C2')
ax1.fill_between(np.average(np.vstack(fprs2), axis = 0), np.std(np.vstack(tprs2), axis = 0) + np.average(np.vstack(tprs2), axis = 0), - np.std(np.vstack(tprs2), axis = 0) + np.average(np.vstack(tprs2), axis = 0), color = 'C0', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(fprg2), axis = 0), np.std(np.vstack(tprg2), axis = 0) + np.average(np.vstack(tprg2), axis = 0), - np.std(np.vstack(tprg2), axis = 0) + np.average(np.vstack(tprg2), axis = 0), color = 'C1', alpha = 0.5)
ax1.fill_between(np.average(np.vstack(fprq2), axis = 0), np.std(np.vstack(tprq2), axis = 0) + np.average(np.vstack(tprq2), axis = 0), - np.std(np.vstack(tprq2), axis = 0) + np.average(np.vstack(tprq2), axis = 0), color = 'C2', alpha = 0.5)

ax1.set_xlabel(r'TPR')
ax1.set_ylabel(r'FPR')
ax1.set_title(r'Baseline')
ax1.legend()

ax2.plot(np.average(np.vstack(fprs2w), axis = 0),np.average(np.vstack(tprs2w), axis = 0), label = r'Star: área média = %.2f'%auc(np.average(np.vstack(fprs2w), axis = 0), np.average(np.vstack(tprs2w), axis = 0)), color = 'C0')
ax2.plot(np.average(np.vstack(fprg2w), axis = 0),np.average(np.vstack(tprg2w), axis = 0), label = r'Galaxy: área média = %.2f'%auc(np.average(np.vstack(fprg2w), axis = 0), np.average(np.vstack(tprg2w), axis = 0)), color = 'C1')
ax2.plot(np.average(np.vstack(fprq2w), axis = 0),np.average(np.vstack(tprq2w), axis = 0), label = r'Quasar: área média = %.2f'%auc(np.average(np.vstack(fprq2w), axis = 0), np.average(np.vstack(tprq2w), axis = 0)), color = 'C2')
ax2.fill_between(np.average(np.vstack(fprs2w), axis = 0), np.std(np.vstack(tprs2w), axis = 0) + np.average(np.vstack(tprs2w), axis = 0), - np.std(np.vstack(tprs2w), axis = 0) + np.average(np.vstack(tprs2w), axis = 0), color = 'C0', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(fprg2w), axis = 0), np.std(np.vstack(tprg2w), axis = 0) + np.average(np.vstack(tprg2w), axis = 0), - np.std(np.vstack(tprg2w), axis = 0) + np.average(np.vstack(tprg2w), axis = 0), color = 'C1', alpha = 0.5)
ax2.fill_between(np.average(np.vstack(fprq2w), axis = 0), np.std(np.vstack(tprq2w), axis = 0) + np.average(np.vstack(tprq2w), axis = 0), - np.std(np.vstack(tprq2w), axis = 0) + np.average(np.vstack(tprq2w), axis = 0), color = 'C2', alpha = 0.5)

ax2.set_xlabel(r'TPR')
ax2.set_ylabel(r'FPR')
ax2.set_title(r'Weighted')
ax2.legend()

# %%
sns.heatmap(cmatrix2, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10')

# %%
sns.heatmap(cmatrix2w, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))

sns.heatmap(cmatrix2, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10', ax = ax1)
ax1.set_title(r'Baseline')
sns.heatmap(cmatrix2w, xticklabels = labels, yticklabels = labels, annot = True, fmt = '10', ax = ax2)
ax2.set_title(r'Weighted')
# Out:
# Text(0.5, 1.0, 'Weighted')

# %%
y_test.value_counts()
# Out:
# 1    18625
# 0    10867
# 2     7439
# Name: class, dtype: int64

# %%
report2 = classification_report(y_test2, np.argmax(test_pred2, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
report2 = pd.DataFrame(report2)
report2.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
report2
# Out:
#                Star    Galaxy       QSO
# precision  0.914691  0.859940  0.745664
# recall     0.813012  0.950389  0.670386
# f1-score   0.860859  0.902905  0.706024

# %%
report2w = classification_report(y_test2w, np.argmax(test_pred2w, axis = 1), target_names = ['Star', 'Galaxy', 'QSO'], output_dict = True)
report2w = pd.DataFrame(report2w)
report2w.drop(index = ['support'], columns = ['accuracy', 'macro avg', 'weighted avg'], inplace = True)
report2w
# Out:
#                Star    Galaxy       QSO
# precision  0.890678  0.897412  0.679939
# recall     0.824699  0.884403  0.778196
# f1-score   0.856419  0.890860  0.725757
